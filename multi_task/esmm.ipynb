# %% [markdown]
# ## ESMM

# %%
import os
import joblib
import numpy as np
import pandas as pd
from collections import namedtuple

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import tensorflow.keras.backend as K
from tensorflow.python.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.preprocessing import  MinMaxScaler, LabelEncoder

from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.metrics import classification_report, roc_curve

# %% [markdown]
# ##### 获取数据

# %%
def get_adult_data():
    """ 读取adult数据集 """
    column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation',
                        'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
                        'income_50k']
    train_df = pd.read_csv(
        '../data/adult/adult.data',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )
    test_df = pd.read_csv(
        '../data/adult/adult.test',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )
    train_df.dropna(inplace=True)
    test_df.dropna(inplace=True)
    test_df['income_50k'] = test_df['income_50k'].apply(lambda x: x[:-1])
    return train_df, test_df
    
train_df, test_df = get_adult_data()
print('train_df.shape: {}, test_df.shape: {}'.format(train_df.shape, test_df.shape))
# Out:
# train_df.shape: (32561, 15), test_df.shape: (16281, 15)

# %% [markdown]
# ##### 数据预处理

# %%
data = pd.concat([train_df, test_df], axis=0)
data['income_50k'] = data['income_50k'].apply(lambda x: 0 if x == ' <=50K' else 1)
data['marital_status'] = data['marital_status'].apply(lambda x: 0 if x == ' Never-married' else 1)

tasks = ['income_50k', 'marital_status']
dense_column_names =['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss', 'hours_per_week']
sparse_column_names = ['workclass', 'education', 'occupation', 'relationship', 'race', 'sex', 'native_country']

def data_processing(df, dense_column_names, sparse_column_names, tasks):
    df[dense_column_names] = df[dense_column_names].fillna(0.0)
    for f in dense_column_names:
        df[f] = df[f].apply(lambda x: float(x))
        df[f] = df[f].apply(lambda x: np.log(x+1) if x > -1 else -1)
    
    df[sparse_column_names] = df[sparse_column_names].fillna("-1")
    for f in sparse_column_names:
        lbe = LabelEncoder()
        df[f] = lbe.fit_transform(df[f])
    return df[dense_column_names + sparse_column_names + tasks]

df = data_processing(data, dense_column_names, sparse_column_names, tasks)
train_df, test_df = df.iloc[0:train_df.shape[0]], df.iloc[train_df.shape[0]:]
print('train_df.shape:{}, test_df.shape:{}'.format(train_df.shape, test_df.shape))
# Out:
# train_df.shape:(32561, 15), test_df.shape:(16281, 15)

# %% [markdown]
# ##### 模型构建

# %%
SparseFeature = namedtuple('SparseFeature', ['name', 'vocabulary_size', 'embedding_size'])
DenseFeature = namedtuple('DenseFeature', ['name', 'dimension'])
VarLenSparseFeature = namedtuple('VarLenSparseFeature', ['name', 'vocabulary_size', 'embedding_size', 'maxlen'])

feature_columns = [SparseFeature(f, vocabulary_size=df[f].nunique(), embedding_size=4) for f in sparse_column_names] + \
[DenseFeature(f, 1) for f in dense_column_names]
# 模拟用户侧特征和物品侧特征
user_feature_columns = [feature_columns[i] for i in range(len(feature_columns)) if i % 2 == 0]
item_feature_columns = [feature_columns[i] for i in range(len(feature_columns)) if i % 2 == 1]
user_feature_columns, item_feature_columns
# Out:
# ([SparseFeature(name='workclass', vocabulary_size=9, embedding_size=4),
#   SparseFeature(name='occupation', vocabulary_size=15, embedding_size=4),
#   SparseFeature(name='race', vocabulary_size=5, embedding_size=4),
#   SparseFeature(name='native_country', vocabulary_size=42, embedding_size=4),
#   DenseFeature(name='fnlwgt', dimension=1),
#   DenseFeature(name='capital_gain', dimension=1),
#   DenseFeature(name='hours_per_week', dimension=1)],
#  [SparseFeature(name='education', vocabulary_size=16, embedding_size=4),
#   SparseFeature(name='relationship', vocabulary_size=6, embedding_size=4),
#   SparseFeature(name='sex', vocabulary_size=2, embedding_size=4),
#   DenseFeature(name='age', dimension=1),
#   DenseFeature(name='education_num', dimension=1),
#   DenseFeature(name='capital_loss', dimension=1)])

# %%
def model_metric(prob, label, thr=0.5):
    """ 模型评估 """
    # AUC
    fpr, tpr, threshold = metrics.roc_curve(label, prob)
    auc = metrics.auc(fpr, tpr)
    score = metrics.accuracy_score(label, prob > thr)
    # LogLoss
    logloss = log_loss(label, prob)
    print('模型准确率:{}, AUC得分:{}, LogLoss:{}'.format(score, auc, logloss))
    print(classification_report(label, prob > thr, digits=2))
    print('==========================================================')

def build_input_layers(feature_columns):
    """ 构建输入层 """
    dense_input_dict, sparse_input_dict, varlen_sparse_input_dict = {}, {}, {}
    for f in feature_columns:
        if isinstance(f, DenseFeature):
            dense_input_dict[f.name] = Input(shape=(f.dimension, ), name=f.name)
        elif isinstance(f, SparseFeature):
            sparse_input_dict[f.name] = Input(shape=(1, ), name=f.name)
        elif isinstance(f, VarLenSparseFeature):
            varlen_sparse_input_dict[f.name] = Input(shape=(f.maxlen, ), name=f.name)
    return dense_input_dict, sparse_input_dict, varlen_sparse_input_dict

def build_embedding_layers(feature_columns):
    """ 构建embedding层 """
    embedding_layer_dict = {}
    for f in feature_columns:
        if isinstance(f, SparseFeature):
            embedding_layer_dict[f.name] = Embedding(f.vocabulary_size+1, f.embedding_size, name='emb_' + f.name)
        elif isinstance(f, VarLenSparseFeature):
            embedding_layer_dict[f.name] = Embedding(f.vocabulary_size+1, f.embedding_size, name='var_emb_' + f.name, mask_zero=True)
    return embedding_layer_dict

def embedding_lookup(columns, input_dict, embedding_layer_dict, flatten=False):
    """ 根据feature_columns或column_names查表，得到对应embedding向量列表 """
    embedding_list = []
    for f in columns:
        if type(f) == str:
            column_name = f
        else:
            column_name = f.name
        _input = input_dict[column_name]
        _embed = embedding_layer_dict[column_name]
        embed_layer = _embed(_input)
        if flatten:
            embed_layer = Flatten()(embed_layer)
        embedding_list.append(embed_layer)
    return embedding_list

def concat_input_list(input_list):
    """ 合并input列表 """
    _num = len(input_list)
    if _num > 1:
        return Concatenate(axis=1)(input_list)
    elif len(input_list) == 1:
        return input_list[0]
    else:
        return None

def get_dnn(dnn_input, hidden_units=[64, 32], activation='relu', l2=0.01, task_name='ctr_output'):
    dnn_out = dnn_input
    dnn_out = Dropout(0.5)(dnn_out)
    dnn_out = BatchNormalization()(dnn_out)
    
    print('hidden_units: ', hidden_units)
    dnn_list = [Dense(unit, activation=activation, kernel_regularizer=tf.keras.regularizers.l2(l2=l2)) for unit in hidden_units]
    for dnn in dnn_list:
        dnn_out = dnn(dnn_out)#Dropout(0.5)(dnn(dnn_out))
    dnn_out = Dense(1, activation='sigmoid', name=task_name)(dnn_out)
    return dnn_out
    
def ESMM(user_feature_columns,
         item_feature_columns,
         tasks,
         hidden_units=[128, 64]):
    """ Entire Space Multi-task Model """
    # Input
    user_dense_input_dict, user_sparse_input_dict, _ = build_input_layers(user_feature_columns)
    item_dense_input_dict, item_sparse_input_dict, _ = build_input_layers(item_feature_columns)

    user_input_list = list(user_dense_input_dict.values()) + list(user_sparse_input_dict.values())
    item_input_list = list(item_dense_input_dict.values()) + list(item_sparse_input_dict.values())
    
    # 用户侧
    user_dense_input_list = list(user_dense_input_dict.values())
    user_embedding_layer_dict = build_embedding_layers(user_feature_columns)
    user_sparse_feature_columns = list(filter(lambda x: isinstance(x, SparseFeature), user_feature_columns))
    flatten_user_sparse_embed_list = embedding_lookup(user_sparse_feature_columns, user_sparse_input_dict, user_embedding_layer_dict, flatten=True)
    user_dnn_input = concat_input_list(user_dense_input_list + flatten_user_sparse_embed_list)
    
    # 物品侧
    item_dense_input_list = list(item_dense_input_dict.values())
    item_embedding_layer_dict = build_embedding_layers(item_feature_columns)
    item_sparse_feature_columns = list(filter(lambda x: isinstance(x, SparseFeature), item_feature_columns))
    flatten_item_sparse_embed_list = embedding_lookup(item_sparse_feature_columns, item_sparse_input_dict, item_embedding_layer_dict, flatten=True)
    item_dnn_input = concat_input_list(item_dense_input_list + flatten_item_sparse_embed_list)
    
    # 合并用户侧物品侧向量
    concat_user_item = Concatenate(axis=1)([user_dnn_input, item_dnn_input])
    
    # Ctr Cvr Tower
    ctr_out = get_dnn(concat_user_item, task_name='ctr_output')
    cvr_out = get_dnn(concat_user_item, task_name='cvr_output')
    ctcvr_out = tf.multiply(ctr_out, cvr_out)
    
    model = Model(user_input_list+item_input_list, outputs=[ctr_out, ctcvr_out])
    return model

model= ESMM(user_feature_columns,
            item_feature_columns,
            tasks,
            hidden_units=[128, 64])
model.summary()
# Out:
# hidden_units:  [64, 32]
# hidden_units:  [64, 32]
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# workclass (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# occupation (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# race (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# native_country (InputLayer)     [(None, 1)]          0
# __________________________________________________________________________________________________
# education (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# relationship (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# sex (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# emb_workclass (Embedding)       (None, 1, 4)         40          workclass[0][0]
# __________________________________________________________________________________________________
# emb_occupation (Embedding)      (None, 1, 4)         64          occupation[0][0]
# __________________________________________________________________________________________________
# emb_race (Embedding)            (None, 1, 4)         24          race[0][0]
# __________________________________________________________________________________________________
# emb_native_country (Embedding)  (None, 1, 4)         172         native_country[0][0]
# __________________________________________________________________________________________________
# emb_education (Embedding)       (None, 1, 4)         68          education[0][0]
# __________________________________________________________________________________________________
# emb_relationship (Embedding)    (None, 1, 4)         28          relationship[0][0]
# __________________________________________________________________________________________________
# emb_sex (Embedding)             (None, 1, 4)         12          sex[0][0]
# __________________________________________________________________________________________________
# fnlwgt (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# capital_gain (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# hours_per_week (InputLayer)     [(None, 1)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4)            0           emb_workclass[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4)            0           emb_occupation[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 4)            0           emb_race[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 4)            0           emb_native_country[0][0]
# __________________________________________________________________________________________________
# age (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# education_num (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# capital_loss (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 4)            0           emb_education[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 4)            0           emb_relationship[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 4)            0           emb_sex[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 19)           0           fnlwgt[0][0]
#                                                                  capital_gain[0][0]
#                                                                  hours_per_week[0][0]
#                                                                  flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 15)           0           age[0][0]
#                                                                  education_num[0][0]
#                                                                  capital_loss[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 34)           0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 34)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 34)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 34)           136         dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 34)           136         dropout_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           2240        batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           2240        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           2080        dense[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           2080        dense_2[0][0]
# __________________________________________________________________________________________________
# ctr_output (Dense)              (None, 1)            33          dense_1[0][0]
# __________________________________________________________________________________________________
# cvr_output (Dense)              (None, 1)            33          dense_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 1)            0           ctr_output[0][0]
#                                                                  cvr_output[0][0]
# ==================================================================================================
# Total params: 9,386
# Trainable params: 9,250
# Non-trainable params: 136
# __________________________________________________________________________________________________

# %%
train_input = {f: train_df[f] for f in dense_column_names + sparse_column_names}
test_input = {f: test_df[f] for f in dense_column_names + sparse_column_names}

# %%
#filepath = "./checkpoints/esmm_best.h5"
my_callbacks = [
    #ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=2, min_lr=0.0001, verbose=1),
    EarlyStopping(monitor='val_loss', patience=10, verbose=2, mode='auto')
]
model.compile('adam',
              loss=['binary_crossentropy', 'binary_crossentropy'],
              loss_weights=[1.0, 1.0],
              metrics=["binary_crossentropy", tf.keras.metrics.AUC(name='auc')])

y_list = [train_df[i].values for i in tasks]
model.fit(train_input,
          y_list,
          batch_size=1024,
          epochs=100,
          validation_split=0.2,
          callbacks=my_callbacks)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 2s 24ms/step - loss: 3.0222 - ctr_output_loss: 0.6817 - tf.math.multiply_loss: 0.7732 - ctr_output_binary_crossentropy: 0.6817 - ctr_output_auc: 0.6514 - tf.math.multiply_binary_crossentropy: 0.7732 - tf.math.multiply_auc: 0.6528 - val_loss: 2.7724 - val_ctr_output_loss: 0.6301 - val_tf.math.multiply_loss: 0.7647 - val_ctr_output_binary_crossentropy: 0.6301 - val_ctr_output_auc: 0.8161 - val_tf.math.multiply_binary_crossentropy: 0.7647 - val_tf.math.multiply_auc: 0.8717
# Epoch 2/100
# 26/26 [==============================] - 0s 6ms/step - loss: 2.4488 - ctr_output_loss: 0.5772 - tf.math.multiply_loss: 0.6498 - ctr_output_binary_crossentropy: 0.5772 - ctr_output_auc: 0.7996 - tf.math.multiply_binary_crossentropy: 0.6498 - tf.math.multiply_auc: 0.8221 - val_loss: 2.4111 - val_ctr_output_loss: 0.6173 - val_tf.math.multiply_loss: 0.7381 - val_ctr_output_binary_crossentropy: 0.6173 - val_ctr_output_auc: 0.8587 - val_tf.math.multiply_binary_crossentropy: 0.7381 - val_tf.math.multiply_auc: 0.8822
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 2.0747 - ctr_output_loss: 0.5585 - tf.math.multiply_loss: 0.5900 - ctr_output_binary_crossentropy: 0.5585 - ctr_output_auc: 0.8235 - tf.math.multiply_binary_crossentropy: 0.5900 - tf.math.multiply_auc: 0.8711 - val_loss: 2.1314 - val_ctr_output_loss: 0.6031 - val_tf.math.multiply_loss: 0.7371 - val_ctr_output_binary_crossentropy: 0.6031 - val_ctr_output_auc: 0.8631 - val_tf.math.multiply_binary_crossentropy: 0.7371 - val_tf.math.multiply_auc: 0.8856
# Epoch 4/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.8107 - ctr_output_loss: 0.5522 - tf.math.multiply_loss: 0.5675 - ctr_output_binary_crossentropy: 0.5522 - ctr_output_auc: 0.8315 - tf.math.multiply_binary_crossentropy: 0.5675 - tf.math.multiply_auc: 0.8900 - val_loss: 1.8945 - val_ctr_output_loss: 0.5964 - val_tf.math.multiply_loss: 0.7091 - val_ctr_output_binary_crossentropy: 0.5964 - val_ctr_output_auc: 0.8693 - val_tf.math.multiply_binary_crossentropy: 0.7091 - val_tf.math.multiply_auc: 0.8903
# Epoch 5/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.6201 - ctr_output_loss: 0.5504 - tf.math.multiply_loss: 0.5560 - ctr_output_binary_crossentropy: 0.5504 - ctr_output_auc: 0.8369 - tf.math.multiply_binary_crossentropy: 0.5560 - tf.math.multiply_auc: 0.8942 - val_loss: 1.7117 - val_ctr_output_loss: 0.5784 - val_tf.math.multiply_loss: 0.6966 - val_ctr_output_binary_crossentropy: 0.5784 - val_ctr_output_auc: 0.8741 - val_tf.math.multiply_binary_crossentropy: 0.6966 - val_tf.math.multiply_auc: 0.9029
# Epoch 6/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.4774 - ctr_output_loss: 0.5465 - tf.math.multiply_loss: 0.5503 - ctr_output_binary_crossentropy: 0.5465 - ctr_output_auc: 0.8394 - tf.math.multiply_binary_crossentropy: 0.5503 - tf.math.multiply_auc: 0.8981 - val_loss: 1.5682 - val_ctr_output_loss: 0.5673 - val_tf.math.multiply_loss: 0.6777 - val_ctr_output_binary_crossentropy: 0.5673 - val_ctr_output_auc: 0.8752 - val_tf.math.multiply_binary_crossentropy: 0.6777 - val_tf.math.multiply_auc: 0.9068
# Epoch 7/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.3759 - ctr_output_loss: 0.5471 - tf.math.multiply_loss: 0.5472 - ctr_output_binary_crossentropy: 0.5471 - ctr_output_auc: 0.8402 - tf.math.multiply_binary_crossentropy: 0.5472 - tf.math.multiply_auc: 0.8996 - val_loss: 1.4543 - val_ctr_output_loss: 0.5636 - val_tf.math.multiply_loss: 0.6513 - val_ctr_output_binary_crossentropy: 0.5636 - val_ctr_output_auc: 0.8814 - val_tf.math.multiply_binary_crossentropy: 0.6513 - val_tf.math.multiply_auc: 0.9117
# Epoch 8/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.2983 - ctr_output_loss: 0.5435 - tf.math.multiply_loss: 0.5459 - ctr_output_binary_crossentropy: 0.5435 - ctr_output_auc: 0.8397 - tf.math.multiply_binary_crossentropy: 0.5459 - tf.math.multiply_auc: 0.9018 - val_loss: 1.3652 - val_ctr_output_loss: 0.5579 - val_tf.math.multiply_loss: 0.6288 - val_ctr_output_binary_crossentropy: 0.5579 - val_ctr_output_auc: 0.8813 - val_tf.math.multiply_binary_crossentropy: 0.6288 - val_tf.math.multiply_auc: 0.9124
# Epoch 9/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.2423 - ctr_output_loss: 0.5434 - tf.math.multiply_loss: 0.5429 - ctr_output_binary_crossentropy: 0.5434 - ctr_output_auc: 0.8410 - tf.math.multiply_binary_crossentropy: 0.5429 - tf.math.multiply_auc: 0.9015 - val_loss: 1.2990 - val_ctr_output_loss: 0.5584 - val_tf.math.multiply_loss: 0.6072 - val_ctr_output_binary_crossentropy: 0.5584 - val_ctr_output_auc: 0.8787 - val_tf.math.multiply_binary_crossentropy: 0.6072 - val_tf.math.multiply_auc: 0.9177
# Epoch 10/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.2001 - ctr_output_loss: 0.5410 - tf.math.multiply_loss: 0.5417 - ctr_output_binary_crossentropy: 0.5410 - ctr_output_auc: 0.8439 - tf.math.multiply_binary_crossentropy: 0.5417 - tf.math.multiply_auc: 0.9010 - val_loss: 1.2433 - val_ctr_output_loss: 0.5589 - val_tf.math.multiply_loss: 0.5831 - val_ctr_output_binary_crossentropy: 0.5589 - val_ctr_output_auc: 0.8776 - val_tf.math.multiply_binary_crossentropy: 0.5831 - val_tf.math.multiply_auc: 0.9168
# Epoch 11/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1706 - ctr_output_loss: 0.5436 - tf.math.multiply_loss: 0.5372 - ctr_output_binary_crossentropy: 0.5436 - ctr_output_auc: 0.8434 - tf.math.multiply_binary_crossentropy: 0.5372 - tf.math.multiply_auc: 0.9012 - val_loss: 1.2030 - val_ctr_output_loss: 0.5517 - val_tf.math.multiply_loss: 0.5731 - val_ctr_output_binary_crossentropy: 0.5517 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.5731 - val_tf.math.multiply_auc: 0.9180
# Epoch 12/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1498 - ctr_output_loss: 0.5403 - tf.math.multiply_loss: 0.5396 - ctr_output_binary_crossentropy: 0.5403 - ctr_output_auc: 0.8436 - tf.math.multiply_binary_crossentropy: 0.5396 - tf.math.multiply_auc: 0.9010 - val_loss: 1.1715 - val_ctr_output_loss: 0.5500 - val_tf.math.multiply_loss: 0.5599 - val_ctr_output_binary_crossentropy: 0.5500 - val_ctr_output_auc: 0.8731 - val_tf.math.multiply_binary_crossentropy: 0.5599 - val_tf.math.multiply_auc: 0.9192
# Epoch 13/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1330 - ctr_output_loss: 0.5384 - tf.math.multiply_loss: 0.5386 - ctr_output_binary_crossentropy: 0.5384 - ctr_output_auc: 0.8453 - tf.math.multiply_binary_crossentropy: 0.5386 - tf.math.multiply_auc: 0.9009 - val_loss: 1.1421 - val_ctr_output_loss: 0.5623 - val_tf.math.multiply_loss: 0.5294 - val_ctr_output_binary_crossentropy: 0.5623 - val_ctr_output_auc: 0.8772 - val_tf.math.multiply_binary_crossentropy: 0.5294 - val_tf.math.multiply_auc: 0.9173
# Epoch 14/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1224 - ctr_output_loss: 0.5430 - tf.math.multiply_loss: 0.5331 - ctr_output_binary_crossentropy: 0.5430 - ctr_output_auc: 0.8458 - tf.math.multiply_binary_crossentropy: 0.5331 - tf.math.multiply_auc: 0.9006 - val_loss: 1.1244 - val_ctr_output_loss: 0.5520 - val_tf.math.multiply_loss: 0.5305 - val_ctr_output_binary_crossentropy: 0.5520 - val_ctr_output_auc: 0.8762 - val_tf.math.multiply_binary_crossentropy: 0.5305 - val_tf.math.multiply_auc: 0.9210
# Epoch 15/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1143 - ctr_output_loss: 0.5361 - tf.math.multiply_loss: 0.5390 - ctr_output_binary_crossentropy: 0.5361 - ctr_output_auc: 0.8456 - tf.math.multiply_binary_crossentropy: 0.5390 - tf.math.multiply_auc: 0.9016 - val_loss: 1.1052 - val_ctr_output_loss: 0.5638 - val_tf.math.multiply_loss: 0.5052 - val_ctr_output_binary_crossentropy: 0.5638 - val_ctr_output_auc: 0.8774 - val_tf.math.multiply_binary_crossentropy: 0.5052 - val_tf.math.multiply_auc: 0.9206
# Epoch 16/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1068 - ctr_output_loss: 0.5410 - tf.math.multiply_loss: 0.5315 - ctr_output_binary_crossentropy: 0.5410 - ctr_output_auc: 0.8452 - tf.math.multiply_binary_crossentropy: 0.5315 - tf.math.multiply_auc: 0.9026 - val_loss: 1.0872 - val_ctr_output_loss: 0.5463 - val_tf.math.multiply_loss: 0.5083 - val_ctr_output_binary_crossentropy: 0.5463 - val_ctr_output_auc: 0.8780 - val_tf.math.multiply_binary_crossentropy: 0.5083 - val_tf.math.multiply_auc: 0.9218
# Epoch 17/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1049 - ctr_output_loss: 0.5357 - tf.math.multiply_loss: 0.5383 - ctr_output_binary_crossentropy: 0.5357 - ctr_output_auc: 0.8471 - tf.math.multiply_binary_crossentropy: 0.5383 - tf.math.multiply_auc: 0.8990 - val_loss: 1.0834 - val_ctr_output_loss: 0.5676 - val_tf.math.multiply_loss: 0.4865 - val_ctr_output_binary_crossentropy: 0.5676 - val_ctr_output_auc: 0.8789 - val_tf.math.multiply_binary_crossentropy: 0.4865 - val_tf.math.multiply_auc: 0.9196
# Epoch 18/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1009 - ctr_output_loss: 0.5380 - tf.math.multiply_loss: 0.5347 - ctr_output_binary_crossentropy: 0.5380 - ctr_output_auc: 0.8495 - tf.math.multiply_binary_crossentropy: 0.5347 - tf.math.multiply_auc: 0.8977 - val_loss: 1.0729 - val_ctr_output_loss: 0.5533 - val_tf.math.multiply_loss: 0.4926 - val_ctr_output_binary_crossentropy: 0.5533 - val_ctr_output_auc: 0.8780 - val_tf.math.multiply_binary_crossentropy: 0.4926 - val_tf.math.multiply_auc: 0.9218
# Epoch 19/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.1013 - ctr_output_loss: 0.5393 - tf.math.multiply_loss: 0.5358 - ctr_output_binary_crossentropy: 0.5393 - ctr_output_auc: 0.8439 - tf.math.multiply_binary_crossentropy: 0.5358 - tf.math.multiply_auc: 0.9001 - val_loss: 1.0671 - val_ctr_output_loss: 0.5439 - val_tf.math.multiply_loss: 0.4980 - val_ctr_output_binary_crossentropy: 0.5439 - val_ctr_output_auc: 0.8770 - val_tf.math.multiply_binary_crossentropy: 0.4980 - val_tf.math.multiply_auc: 0.9225
# Epoch 20/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0975 - ctr_output_loss: 0.5387 - tf.math.multiply_loss: 0.5342 - ctr_output_binary_crossentropy: 0.5387 - ctr_output_auc: 0.8459 - tf.math.multiply_binary_crossentropy: 0.5342 - tf.math.multiply_auc: 0.9011 - val_loss: 1.0596 - val_ctr_output_loss: 0.5470 - val_tf.math.multiply_loss: 0.4885 - val_ctr_output_binary_crossentropy: 0.5470 - val_ctr_output_auc: 0.8765 - val_tf.math.multiply_binary_crossentropy: 0.4885 - val_tf.math.multiply_auc: 0.9233
# Epoch 21/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0955 - ctr_output_loss: 0.5386 - tf.math.multiply_loss: 0.5336 - ctr_output_binary_crossentropy: 0.5386 - ctr_output_auc: 0.8466 - tf.math.multiply_binary_crossentropy: 0.5336 - tf.math.multiply_auc: 0.9003 - val_loss: 1.0545 - val_ctr_output_loss: 0.5279 - val_tf.math.multiply_loss: 0.5038 - val_ctr_output_binary_crossentropy: 0.5279 - val_ctr_output_auc: 0.8775 - val_tf.math.multiply_binary_crossentropy: 0.5038 - val_tf.math.multiply_auc: 0.9221
# Epoch 22/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0921 - ctr_output_loss: 0.5364 - tf.math.multiply_loss: 0.5333 - ctr_output_binary_crossentropy: 0.5364 - ctr_output_auc: 0.8470 - tf.math.multiply_binary_crossentropy: 0.5333 - tf.math.multiply_auc: 0.9017 - val_loss: 1.0532 - val_ctr_output_loss: 0.5447 - val_tf.math.multiply_loss: 0.4870 - val_ctr_output_binary_crossentropy: 0.5447 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.4870 - val_tf.math.multiply_auc: 0.9235
# Epoch 23/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0938 - ctr_output_loss: 0.5398 - tf.math.multiply_loss: 0.5327 - ctr_output_binary_crossentropy: 0.5398 - ctr_output_auc: 0.8465 - tf.math.multiply_binary_crossentropy: 0.5327 - tf.math.multiply_auc: 0.9000 - val_loss: 1.0464 - val_ctr_output_loss: 0.5283 - val_tf.math.multiply_loss: 0.4970 - val_ctr_output_binary_crossentropy: 0.5283 - val_ctr_output_auc: 0.8775 - val_tf.math.multiply_binary_crossentropy: 0.4970 - val_tf.math.multiply_auc: 0.9228
# Epoch 24/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0910 - ctr_output_loss: 0.5360 - tf.math.multiply_loss: 0.5346 - ctr_output_binary_crossentropy: 0.5360 - ctr_output_auc: 0.8475 - tf.math.multiply_binary_crossentropy: 0.5346 - tf.math.multiply_auc: 0.9003 - val_loss: 1.0448 - val_ctr_output_loss: 0.5388 - val_tf.math.multiply_loss: 0.4858 - val_ctr_output_binary_crossentropy: 0.5388 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.4858 - val_tf.math.multiply_auc: 0.9236
# Epoch 25/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0902 - ctr_output_loss: 0.5360 - tf.math.multiply_loss: 0.5341 - ctr_output_binary_crossentropy: 0.5360 - ctr_output_auc: 0.8473 - tf.math.multiply_binary_crossentropy: 0.5341 - tf.math.multiply_auc: 0.9005 - val_loss: 1.0464 - val_ctr_output_loss: 0.5341 - val_tf.math.multiply_loss: 0.4931 - val_ctr_output_binary_crossentropy: 0.5341 - val_ctr_output_auc: 0.8765 - val_tf.math.multiply_binary_crossentropy: 0.4931 - val_tf.math.multiply_auc: 0.9220
# Epoch 26/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0892 - ctr_output_loss: 0.5368 - tf.math.multiply_loss: 0.5332 - ctr_output_binary_crossentropy: 0.5368 - ctr_output_auc: 0.8466 - tf.math.multiply_binary_crossentropy: 0.5332 - tf.math.multiply_auc: 0.9018 - val_loss: 1.0413 - val_ctr_output_loss: 0.5271 - val_tf.math.multiply_loss: 0.4951 - val_ctr_output_binary_crossentropy: 0.5271 - val_ctr_output_auc: 0.8769 - val_tf.math.multiply_binary_crossentropy: 0.4951 - val_tf.math.multiply_auc: 0.9223
# Epoch 27/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0844 - ctr_output_loss: 0.5360 - tf.math.multiply_loss: 0.5296 - ctr_output_binary_crossentropy: 0.5360 - ctr_output_auc: 0.8513 - tf.math.multiply_binary_crossentropy: 0.5296 - tf.math.multiply_auc: 0.9019 - val_loss: 1.0395 - val_ctr_output_loss: 0.5230 - val_tf.math.multiply_loss: 0.4981 - val_ctr_output_binary_crossentropy: 0.5230 - val_ctr_output_auc: 0.8764 - val_tf.math.multiply_binary_crossentropy: 0.4981 - val_tf.math.multiply_auc: 0.9246
# Epoch 28/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0874 - ctr_output_loss: 0.5336 - tf.math.multiply_loss: 0.5356 - ctr_output_binary_crossentropy: 0.5336 - ctr_output_auc: 0.8479 - tf.math.multiply_binary_crossentropy: 0.5356 - tf.math.multiply_auc: 0.9010 - val_loss: 1.0406 - val_ctr_output_loss: 0.5348 - val_tf.math.multiply_loss: 0.4883 - val_ctr_output_binary_crossentropy: 0.5348 - val_ctr_output_auc: 0.8769 - val_tf.math.multiply_binary_crossentropy: 0.4883 - val_tf.math.multiply_auc: 0.9225
# Epoch 29/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0857 - ctr_output_loss: 0.5403 - tf.math.multiply_loss: 0.5280 - ctr_output_binary_crossentropy: 0.5403 - ctr_output_auc: 0.8493 - tf.math.multiply_binary_crossentropy: 0.5280 - tf.math.multiply_auc: 0.9009 - val_loss: 1.0373 - val_ctr_output_loss: 0.5200 - val_tf.math.multiply_loss: 0.4995 - val_ctr_output_binary_crossentropy: 0.5200 - val_ctr_output_auc: 0.8756 - val_tf.math.multiply_binary_crossentropy: 0.4995 - val_tf.math.multiply_auc: 0.9235
# Epoch 30/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0873 - ctr_output_loss: 0.5378 - tf.math.multiply_loss: 0.5323 - ctr_output_binary_crossentropy: 0.5378 - ctr_output_auc: 0.8467 - tf.math.multiply_binary_crossentropy: 0.5323 - tf.math.multiply_auc: 0.9014 - val_loss: 1.0396 - val_ctr_output_loss: 0.5205 - val_tf.math.multiply_loss: 0.5027 - val_ctr_output_binary_crossentropy: 0.5205 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.5027 - val_tf.math.multiply_auc: 0.9229
# Epoch 31/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0850 - ctr_output_loss: 0.5325 - tf.math.multiply_loss: 0.5359 - ctr_output_binary_crossentropy: 0.5325 - ctr_output_auc: 0.8491 - tf.math.multiply_binary_crossentropy: 0.5359 - tf.math.multiply_auc: 0.9009 - val_loss: 1.0362 - val_ctr_output_loss: 0.5276 - val_tf.math.multiply_loss: 0.4920 - val_ctr_output_binary_crossentropy: 0.5276 - val_ctr_output_auc: 0.8769 - val_tf.math.multiply_binary_crossentropy: 0.4920 - val_tf.math.multiply_auc: 0.9221
# Epoch 32/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0848 - ctr_output_loss: 0.5387 - tf.math.multiply_loss: 0.5296 - ctr_output_binary_crossentropy: 0.5387 - ctr_output_auc: 0.8479 - tf.math.multiply_binary_crossentropy: 0.5296 - tf.math.multiply_auc: 0.9006 - val_loss: 1.0360 - val_ctr_output_loss: 0.5315 - val_tf.math.multiply_loss: 0.4883 - val_ctr_output_binary_crossentropy: 0.5315 - val_ctr_output_auc: 0.8756 - val_tf.math.multiply_binary_crossentropy: 0.4883 - val_tf.math.multiply_auc: 0.9240
# Epoch 33/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0843 - ctr_output_loss: 0.5355 - tf.math.multiply_loss: 0.5330 - ctr_output_binary_crossentropy: 0.5355 - ctr_output_auc: 0.8469 - tf.math.multiply_binary_crossentropy: 0.5330 - tf.math.multiply_auc: 0.9029 - val_loss: 1.0352 - val_ctr_output_loss: 0.5344 - val_tf.math.multiply_loss: 0.4850 - val_ctr_output_binary_crossentropy: 0.5344 - val_ctr_output_auc: 0.8771 - val_tf.math.multiply_binary_crossentropy: 0.4850 - val_tf.math.multiply_auc: 0.9222
# Epoch 34/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0824 - ctr_output_loss: 0.5387 - tf.math.multiply_loss: 0.5282 - ctr_output_binary_crossentropy: 0.5387 - ctr_output_auc: 0.8487 - tf.math.multiply_binary_crossentropy: 0.5282 - tf.math.multiply_auc: 0.9006 - val_loss: 1.0355 - val_ctr_output_loss: 0.5305 - val_tf.math.multiply_loss: 0.4895 - val_ctr_output_binary_crossentropy: 0.5305 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.4895 - val_tf.math.multiply_auc: 0.9224
# Epoch 35/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0821 - ctr_output_loss: 0.5337 - tf.math.multiply_loss: 0.5328 - ctr_output_binary_crossentropy: 0.5337 - ctr_output_auc: 0.8496 - tf.math.multiply_binary_crossentropy: 0.5328 - tf.math.multiply_auc: 0.9013 - val_loss: 1.0356 - val_ctr_output_loss: 0.5106 - val_tf.math.multiply_loss: 0.5097 - val_ctr_output_binary_crossentropy: 0.5106 - val_ctr_output_auc: 0.8749 - val_tf.math.multiply_binary_crossentropy: 0.5097 - val_tf.math.multiply_auc: 0.9245
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 36/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0832 - ctr_output_loss: 0.5358 - tf.math.multiply_loss: 0.5324 - ctr_output_binary_crossentropy: 0.5358 - ctr_output_auc: 0.8468 - tf.math.multiply_binary_crossentropy: 0.5324 - tf.math.multiply_auc: 0.9021 - val_loss: 1.0345 - val_ctr_output_loss: 0.5255 - val_tf.math.multiply_loss: 0.4939 - val_ctr_output_binary_crossentropy: 0.5255 - val_ctr_output_auc: 0.8754 - val_tf.math.multiply_binary_crossentropy: 0.4939 - val_tf.math.multiply_auc: 0.9231
# Epoch 37/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0803 - ctr_output_loss: 0.5378 - tf.math.multiply_loss: 0.5274 - ctr_output_binary_crossentropy: 0.5378 - ctr_output_auc: 0.8505 - tf.math.multiply_binary_crossentropy: 0.5274 - tf.math.multiply_auc: 0.9007 - val_loss: 1.0354 - val_ctr_output_loss: 0.5056 - val_tf.math.multiply_loss: 0.5147 - val_ctr_output_binary_crossentropy: 0.5056 - val_ctr_output_auc: 0.8751 - val_tf.math.multiply_binary_crossentropy: 0.5147 - val_tf.math.multiply_auc: 0.9257
# Epoch 38/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0804 - ctr_output_loss: 0.5327 - tf.math.multiply_loss: 0.5327 - ctr_output_binary_crossentropy: 0.5327 - ctr_output_auc: 0.8481 - tf.math.multiply_binary_crossentropy: 0.5327 - tf.math.multiply_auc: 0.9030 - val_loss: 1.0336 - val_ctr_output_loss: 0.5212 - val_tf.math.multiply_loss: 0.4977 - val_ctr_output_binary_crossentropy: 0.5212 - val_ctr_output_auc: 0.8763 - val_tf.math.multiply_binary_crossentropy: 0.4977 - val_tf.math.multiply_auc: 0.9231
# Epoch 39/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0797 - ctr_output_loss: 0.5369 - tf.math.multiply_loss: 0.5283 - ctr_output_binary_crossentropy: 0.5369 - ctr_output_auc: 0.8507 - tf.math.multiply_binary_crossentropy: 0.5283 - tf.math.multiply_auc: 0.9009 - val_loss: 1.0336 - val_ctr_output_loss: 0.5204 - val_tf.math.multiply_loss: 0.4989 - val_ctr_output_binary_crossentropy: 0.5204 - val_ctr_output_auc: 0.8751 - val_tf.math.multiply_binary_crossentropy: 0.4989 - val_tf.math.multiply_auc: 0.9249
# Epoch 40/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0792 - ctr_output_loss: 0.5375 - tf.math.multiply_loss: 0.5273 - ctr_output_binary_crossentropy: 0.5375 - ctr_output_auc: 0.8482 - tf.math.multiply_binary_crossentropy: 0.5273 - tf.math.multiply_auc: 0.9037 - val_loss: 1.0338 - val_ctr_output_loss: 0.5259 - val_tf.math.multiply_loss: 0.4938 - val_ctr_output_binary_crossentropy: 0.5259 - val_ctr_output_auc: 0.8752 - val_tf.math.multiply_binary_crossentropy: 0.4938 - val_tf.math.multiply_auc: 0.9236
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 41/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0789 - ctr_output_loss: 0.5335 - tf.math.multiply_loss: 0.5312 - ctr_output_binary_crossentropy: 0.5335 - ctr_output_auc: 0.8495 - tf.math.multiply_binary_crossentropy: 0.5312 - tf.math.multiply_auc: 0.9027 - val_loss: 1.0326 - val_ctr_output_loss: 0.5128 - val_tf.math.multiply_loss: 0.5055 - val_ctr_output_binary_crossentropy: 0.5128 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.5055 - val_tf.math.multiply_auc: 0.9238
# Epoch 42/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0794 - ctr_output_loss: 0.5339 - tf.math.multiply_loss: 0.5313 - ctr_output_binary_crossentropy: 0.5339 - ctr_output_auc: 0.8509 - tf.math.multiply_binary_crossentropy: 0.5313 - tf.math.multiply_auc: 0.9014 - val_loss: 1.0325 - val_ctr_output_loss: 0.5281 - val_tf.math.multiply_loss: 0.4905 - val_ctr_output_binary_crossentropy: 0.5281 - val_ctr_output_auc: 0.8764 - val_tf.math.multiply_binary_crossentropy: 0.4905 - val_tf.math.multiply_auc: 0.9239
# Epoch 43/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0803 - ctr_output_loss: 0.5383 - tf.math.multiply_loss: 0.5283 - ctr_output_binary_crossentropy: 0.5383 - ctr_output_auc: 0.8476 - tf.math.multiply_binary_crossentropy: 0.5283 - tf.math.multiply_auc: 0.9021 - val_loss: 1.0327 - val_ctr_output_loss: 0.5183 - val_tf.math.multiply_loss: 0.5007 - val_ctr_output_binary_crossentropy: 0.5183 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.5007 - val_tf.math.multiply_auc: 0.9231
# Epoch 44/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0819 - ctr_output_loss: 0.5360 - tf.math.multiply_loss: 0.5323 - ctr_output_binary_crossentropy: 0.5360 - ctr_output_auc: 0.8481 - tf.math.multiply_binary_crossentropy: 0.5323 - tf.math.multiply_auc: 0.9006 - val_loss: 1.0326 - val_ctr_output_loss: 0.5293 - val_tf.math.multiply_loss: 0.4897 - val_ctr_output_binary_crossentropy: 0.5293 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.4897 - val_tf.math.multiply_auc: 0.9230
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 45/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0760 - ctr_output_loss: 0.5363 - tf.math.multiply_loss: 0.5261 - ctr_output_binary_crossentropy: 0.5363 - ctr_output_auc: 0.8520 - tf.math.multiply_binary_crossentropy: 0.5261 - tf.math.multiply_auc: 0.9027 - val_loss: 1.0314 - val_ctr_output_loss: 0.5126 - val_tf.math.multiply_loss: 0.5051 - val_ctr_output_binary_crossentropy: 0.5126 - val_ctr_output_auc: 0.8762 - val_tf.math.multiply_binary_crossentropy: 0.5051 - val_tf.math.multiply_auc: 0.9237
# Epoch 46/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0807 - ctr_output_loss: 0.5349 - tf.math.multiply_loss: 0.5325 - ctr_output_binary_crossentropy: 0.5349 - ctr_output_auc: 0.8481 - tf.math.multiply_binary_crossentropy: 0.5325 - tf.math.multiply_auc: 0.9015 - val_loss: 1.0317 - val_ctr_output_loss: 0.5176 - val_tf.math.multiply_loss: 0.5009 - val_ctr_output_binary_crossentropy: 0.5176 - val_ctr_output_auc: 0.8771 - val_tf.math.multiply_binary_crossentropy: 0.5009 - val_tf.math.multiply_auc: 0.9222
# Epoch 47/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0788 - ctr_output_loss: 0.5383 - tf.math.multiply_loss: 0.5273 - ctr_output_binary_crossentropy: 0.5383 - ctr_output_auc: 0.8498 - tf.math.multiply_binary_crossentropy: 0.5273 - tf.math.multiply_auc: 0.9007 - val_loss: 1.0317 - val_ctr_output_loss: 0.5221 - val_tf.math.multiply_loss: 0.4964 - val_ctr_output_binary_crossentropy: 0.5221 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.4964 - val_tf.math.multiply_auc: 0.9223
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 48/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0796 - ctr_output_loss: 0.5303 - tf.math.multiply_loss: 0.5361 - ctr_output_binary_crossentropy: 0.5303 - ctr_output_auc: 0.8499 - tf.math.multiply_binary_crossentropy: 0.5361 - tf.math.multiply_auc: 0.9005 - val_loss: 1.0320 - val_ctr_output_loss: 0.5323 - val_tf.math.multiply_loss: 0.4866 - val_ctr_output_binary_crossentropy: 0.5323 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4866 - val_tf.math.multiply_auc: 0.9227
# Epoch 49/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0796 - ctr_output_loss: 0.5397 - tf.math.multiply_loss: 0.5269 - ctr_output_binary_crossentropy: 0.5397 - ctr_output_auc: 0.8471 - tf.math.multiply_binary_crossentropy: 0.5269 - tf.math.multiply_auc: 0.9023 - val_loss: 1.0314 - val_ctr_output_loss: 0.5264 - val_tf.math.multiply_loss: 0.4920 - val_ctr_output_binary_crossentropy: 0.5264 - val_ctr_output_auc: 0.8765 - val_tf.math.multiply_binary_crossentropy: 0.4920 - val_tf.math.multiply_auc: 0.9230
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 50/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0766 - ctr_output_loss: 0.5339 - tf.math.multiply_loss: 0.5297 - ctr_output_binary_crossentropy: 0.5339 - ctr_output_auc: 0.8518 - tf.math.multiply_binary_crossentropy: 0.5297 - tf.math.multiply_auc: 0.9019 - val_loss: 1.0312 - val_ctr_output_loss: 0.5275 - val_tf.math.multiply_loss: 0.4907 - val_ctr_output_binary_crossentropy: 0.5275 - val_ctr_output_auc: 0.8770 - val_tf.math.multiply_binary_crossentropy: 0.4907 - val_tf.math.multiply_auc: 0.9227
# Epoch 51/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0755 - ctr_output_loss: 0.5337 - tf.math.multiply_loss: 0.5288 - ctr_output_binary_crossentropy: 0.5337 - ctr_output_auc: 0.8522 - tf.math.multiply_binary_crossentropy: 0.5288 - tf.math.multiply_auc: 0.9024 - val_loss: 1.0312 - val_ctr_output_loss: 0.5289 - val_tf.math.multiply_loss: 0.4894 - val_ctr_output_binary_crossentropy: 0.5289 - val_ctr_output_auc: 0.8764 - val_tf.math.multiply_binary_crossentropy: 0.4894 - val_tf.math.multiply_auc: 0.9232
# Epoch 52/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0770 - ctr_output_loss: 0.5362 - tf.math.multiply_loss: 0.5279 - ctr_output_binary_crossentropy: 0.5362 - ctr_output_auc: 0.8480 - tf.math.multiply_binary_crossentropy: 0.5279 - tf.math.multiply_auc: 0.9039 - val_loss: 1.0307 - val_ctr_output_loss: 0.5158 - val_tf.math.multiply_loss: 0.5019 - val_ctr_output_binary_crossentropy: 0.5158 - val_ctr_output_auc: 0.8757 - val_tf.math.multiply_binary_crossentropy: 0.5019 - val_tf.math.multiply_auc: 0.9239
# Epoch 53/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0752 - ctr_output_loss: 0.5358 - tf.math.multiply_loss: 0.5265 - ctr_output_binary_crossentropy: 0.5358 - ctr_output_auc: 0.8500 - tf.math.multiply_binary_crossentropy: 0.5265 - tf.math.multiply_auc: 0.9045 - val_loss: 1.0307 - val_ctr_output_loss: 0.5199 - val_tf.math.multiply_loss: 0.4979 - val_ctr_output_binary_crossentropy: 0.5199 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.4979 - val_tf.math.multiply_auc: 0.9236
# Epoch 54/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0771 - ctr_output_loss: 0.5346 - tf.math.multiply_loss: 0.5297 - ctr_output_binary_crossentropy: 0.5346 - ctr_output_auc: 0.8506 - tf.math.multiply_binary_crossentropy: 0.5297 - tf.math.multiply_auc: 0.9024 - val_loss: 1.0306 - val_ctr_output_loss: 0.5231 - val_tf.math.multiply_loss: 0.4947 - val_ctr_output_binary_crossentropy: 0.5231 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.4947 - val_tf.math.multiply_auc: 0.9236
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 55/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0779 - ctr_output_loss: 0.5354 - tf.math.multiply_loss: 0.5299 - ctr_output_binary_crossentropy: 0.5354 - ctr_output_auc: 0.8511 - tf.math.multiply_binary_crossentropy: 0.5299 - tf.math.multiply_auc: 0.9016 - val_loss: 1.0308 - val_ctr_output_loss: 0.5213 - val_tf.math.multiply_loss: 0.4969 - val_ctr_output_binary_crossentropy: 0.5213 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.4969 - val_tf.math.multiply_auc: 0.9236
# Epoch 56/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0763 - ctr_output_loss: 0.5353 - tf.math.multiply_loss: 0.5283 - ctr_output_binary_crossentropy: 0.5353 - ctr_output_auc: 0.8513 - tf.math.multiply_binary_crossentropy: 0.5283 - tf.math.multiply_auc: 0.9020 - val_loss: 1.0302 - val_ctr_output_loss: 0.5155 - val_tf.math.multiply_loss: 0.5019 - val_ctr_output_binary_crossentropy: 0.5155 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.5019 - val_tf.math.multiply_auc: 0.9237
# Epoch 57/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0771 - ctr_output_loss: 0.5342 - tf.math.multiply_loss: 0.5302 - ctr_output_binary_crossentropy: 0.5342 - ctr_output_auc: 0.8501 - tf.math.multiply_binary_crossentropy: 0.5302 - tf.math.multiply_auc: 0.9019 - val_loss: 1.0305 - val_ctr_output_loss: 0.5232 - val_tf.math.multiply_loss: 0.4946 - val_ctr_output_binary_crossentropy: 0.5232 - val_ctr_output_auc: 0.8763 - val_tf.math.multiply_binary_crossentropy: 0.4946 - val_tf.math.multiply_auc: 0.9230
# Epoch 58/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0773 - ctr_output_loss: 0.5350 - tf.math.multiply_loss: 0.5296 - ctr_output_binary_crossentropy: 0.5350 - ctr_output_auc: 0.8506 - tf.math.multiply_binary_crossentropy: 0.5296 - tf.math.multiply_auc: 0.9017 - val_loss: 1.0306 - val_ctr_output_loss: 0.5223 - val_tf.math.multiply_loss: 0.4958 - val_ctr_output_binary_crossentropy: 0.5223 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4958 - val_tf.math.multiply_auc: 0.9229
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 59/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0763 - ctr_output_loss: 0.5323 - tf.math.multiply_loss: 0.5315 - ctr_output_binary_crossentropy: 0.5323 - ctr_output_auc: 0.8501 - tf.math.multiply_binary_crossentropy: 0.5315 - tf.math.multiply_auc: 0.9025 - val_loss: 1.0304 - val_ctr_output_loss: 0.5246 - val_tf.math.multiply_loss: 0.4933 - val_ctr_output_binary_crossentropy: 0.5246 - val_ctr_output_auc: 0.8765 - val_tf.math.multiply_binary_crossentropy: 0.4933 - val_tf.math.multiply_auc: 0.9232
# Epoch 60/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0765 - ctr_output_loss: 0.5375 - tf.math.multiply_loss: 0.5266 - ctr_output_binary_crossentropy: 0.5375 - ctr_output_auc: 0.8491 - tf.math.multiply_binary_crossentropy: 0.5266 - tf.math.multiply_auc: 0.9035 - val_loss: 1.0303 - val_ctr_output_loss: 0.5178 - val_tf.math.multiply_loss: 0.4999 - val_ctr_output_binary_crossentropy: 0.5178 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.4999 - val_tf.math.multiply_auc: 0.9231
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 61/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0778 - ctr_output_loss: 0.5347 - tf.math.multiply_loss: 0.5306 - ctr_output_binary_crossentropy: 0.5347 - ctr_output_auc: 0.8484 - tf.math.multiply_binary_crossentropy: 0.5306 - tf.math.multiply_auc: 0.9018 - val_loss: 1.0307 - val_ctr_output_loss: 0.5260 - val_tf.math.multiply_loss: 0.4922 - val_ctr_output_binary_crossentropy: 0.5260 - val_ctr_output_auc: 0.8764 - val_tf.math.multiply_binary_crossentropy: 0.4922 - val_tf.math.multiply_auc: 0.9229
# Epoch 62/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0762 - ctr_output_loss: 0.5354 - tf.math.multiply_loss: 0.5283 - ctr_output_binary_crossentropy: 0.5354 - ctr_output_auc: 0.8512 - tf.math.multiply_binary_crossentropy: 0.5283 - tf.math.multiply_auc: 0.9021 - val_loss: 1.0302 - val_ctr_output_loss: 0.5179 - val_tf.math.multiply_loss: 0.4998 - val_ctr_output_binary_crossentropy: 0.5179 - val_ctr_output_auc: 0.8762 - val_tf.math.multiply_binary_crossentropy: 0.4998 - val_tf.math.multiply_auc: 0.9226
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# Epoch 63/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0749 - ctr_output_loss: 0.5336 - tf.math.multiply_loss: 0.5289 - ctr_output_binary_crossentropy: 0.5336 - ctr_output_auc: 0.8527 - tf.math.multiply_binary_crossentropy: 0.5289 - tf.math.multiply_auc: 0.9019 - val_loss: 1.0305 - val_ctr_output_loss: 0.5229 - val_tf.math.multiply_loss: 0.4952 - val_ctr_output_binary_crossentropy: 0.5229 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4952 - val_tf.math.multiply_auc: 0.9233
# Epoch 64/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0776 - ctr_output_loss: 0.5360 - tf.math.multiply_loss: 0.5293 - ctr_output_binary_crossentropy: 0.5360 - ctr_output_auc: 0.8487 - tf.math.multiply_binary_crossentropy: 0.5293 - tf.math.multiply_auc: 0.9028 - val_loss: 1.0305 - val_ctr_output_loss: 0.5221 - val_tf.math.multiply_loss: 0.4960 - val_ctr_output_binary_crossentropy: 0.5221 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4960 - val_tf.math.multiply_auc: 0.9237
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# Epoch 65/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0780 - ctr_output_loss: 0.5364 - tf.math.multiply_loss: 0.5292 - ctr_output_binary_crossentropy: 0.5364 - ctr_output_auc: 0.8498 - tf.math.multiply_binary_crossentropy: 0.5292 - tf.math.multiply_auc: 0.9014 - val_loss: 1.0304 - val_ctr_output_loss: 0.5192 - val_tf.math.multiply_loss: 0.4988 - val_ctr_output_binary_crossentropy: 0.5192 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.4988 - val_tf.math.multiply_auc: 0.9236
# Epoch 66/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0765 - ctr_output_loss: 0.5378 - tf.math.multiply_loss: 0.5265 - ctr_output_binary_crossentropy: 0.5378 - ctr_output_auc: 0.8478 - tf.math.multiply_binary_crossentropy: 0.5265 - tf.math.multiply_auc: 0.9032 - val_loss: 1.0303 - val_ctr_output_loss: 0.5228 - val_tf.math.multiply_loss: 0.4952 - val_ctr_output_binary_crossentropy: 0.5228 - val_ctr_output_auc: 0.8763 - val_tf.math.multiply_binary_crossentropy: 0.4952 - val_tf.math.multiply_auc: 0.9233
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 67/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0782 - ctr_output_loss: 0.5336 - tf.math.multiply_loss: 0.5323 - ctr_output_binary_crossentropy: 0.5336 - ctr_output_auc: 0.8486 - tf.math.multiply_binary_crossentropy: 0.5323 - tf.math.multiply_auc: 0.9021 - val_loss: 1.0306 - val_ctr_output_loss: 0.5222 - val_tf.math.multiply_loss: 0.4962 - val_ctr_output_binary_crossentropy: 0.5222 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4962 - val_tf.math.multiply_auc: 0.9232
# Epoch 68/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0790 - ctr_output_loss: 0.5381 - tf.math.multiply_loss: 0.5287 - ctr_output_binary_crossentropy: 0.5381 - ctr_output_auc: 0.8492 - tf.math.multiply_binary_crossentropy: 0.5287 - tf.math.multiply_auc: 0.9002 - val_loss: 1.0306 - val_ctr_output_loss: 0.5234 - val_tf.math.multiply_loss: 0.4949 - val_ctr_output_binary_crossentropy: 0.5234 - val_ctr_output_auc: 0.8763 - val_tf.math.multiply_binary_crossentropy: 0.4949 - val_tf.math.multiply_auc: 0.9232
# Epoch 69/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0762 - ctr_output_loss: 0.5342 - tf.math.multiply_loss: 0.5297 - ctr_output_binary_crossentropy: 0.5342 - ctr_output_auc: 0.8502 - tf.math.multiply_binary_crossentropy: 0.5297 - tf.math.multiply_auc: 0.9022 - val_loss: 1.0304 - val_ctr_output_loss: 0.5249 - val_tf.math.multiply_loss: 0.4932 - val_ctr_output_binary_crossentropy: 0.5249 - val_ctr_output_auc: 0.8763 - val_tf.math.multiply_binary_crossentropy: 0.4932 - val_tf.math.multiply_auc: 0.9230
# Epoch 70/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0718 - ctr_output_loss: 0.5323 - tf.math.multiply_loss: 0.5273 - ctr_output_binary_crossentropy: 0.5323 - ctr_output_auc: 0.8533 - tf.math.multiply_binary_crossentropy: 0.5273 - tf.math.multiply_auc: 0.9036 - val_loss: 1.0302 - val_ctr_output_loss: 0.5251 - val_tf.math.multiply_loss: 0.4928 - val_ctr_output_binary_crossentropy: 0.5251 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.4928 - val_tf.math.multiply_auc: 0.9231
# Epoch 71/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0755 - ctr_output_loss: 0.5332 - tf.math.multiply_loss: 0.5300 - ctr_output_binary_crossentropy: 0.5332 - ctr_output_auc: 0.8514 - tf.math.multiply_binary_crossentropy: 0.5300 - tf.math.multiply_auc: 0.9026 - val_loss: 1.0302 - val_ctr_output_loss: 0.5242 - val_tf.math.multiply_loss: 0.4937 - val_ctr_output_binary_crossentropy: 0.5242 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.4937 - val_tf.math.multiply_auc: 0.9232
# Epoch 72/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0740 - ctr_output_loss: 0.5363 - tf.math.multiply_loss: 0.5255 - ctr_output_binary_crossentropy: 0.5363 - ctr_output_auc: 0.8512 - tf.math.multiply_binary_crossentropy: 0.5255 - tf.math.multiply_auc: 0.9037 - val_loss: 1.0304 - val_ctr_output_loss: 0.5218 - val_tf.math.multiply_loss: 0.4963 - val_ctr_output_binary_crossentropy: 0.5218 - val_ctr_output_auc: 0.8757 - val_tf.math.multiply_binary_crossentropy: 0.4963 - val_tf.math.multiply_auc: 0.9232
# Epoch 73/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0768 - ctr_output_loss: 0.5363 - tf.math.multiply_loss: 0.5284 - ctr_output_binary_crossentropy: 0.5363 - ctr_output_auc: 0.8488 - tf.math.multiply_binary_crossentropy: 0.5284 - tf.math.multiply_auc: 0.9035 - val_loss: 1.0306 - val_ctr_output_loss: 0.5237 - val_tf.math.multiply_loss: 0.4947 - val_ctr_output_binary_crossentropy: 0.5237 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4947 - val_tf.math.multiply_auc: 0.9228
# Epoch 74/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0768 - ctr_output_loss: 0.5335 - tf.math.multiply_loss: 0.5311 - ctr_output_binary_crossentropy: 0.5335 - ctr_output_auc: 0.8504 - tf.math.multiply_binary_crossentropy: 0.5311 - tf.math.multiply_auc: 0.9018 - val_loss: 1.0305 - val_ctr_output_loss: 0.5223 - val_tf.math.multiply_loss: 0.4960 - val_ctr_output_binary_crossentropy: 0.5223 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.4960 - val_tf.math.multiply_auc: 0.9231
# Epoch 75/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0740 - ctr_output_loss: 0.5319 - tf.math.multiply_loss: 0.5298 - ctr_output_binary_crossentropy: 0.5319 - ctr_output_auc: 0.8525 - tf.math.multiply_binary_crossentropy: 0.5298 - tf.math.multiply_auc: 0.9026 - val_loss: 1.0299 - val_ctr_output_loss: 0.5221 - val_tf.math.multiply_loss: 0.4956 - val_ctr_output_binary_crossentropy: 0.5221 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.4956 - val_tf.math.multiply_auc: 0.9234
# Epoch 76/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0752 - ctr_output_loss: 0.5366 - tf.math.multiply_loss: 0.5264 - ctr_output_binary_crossentropy: 0.5366 - ctr_output_auc: 0.8503 - tf.math.multiply_binary_crossentropy: 0.5264 - tf.math.multiply_auc: 0.9035 - val_loss: 1.0301 - val_ctr_output_loss: 0.5244 - val_tf.math.multiply_loss: 0.4935 - val_ctr_output_binary_crossentropy: 0.5244 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4935 - val_tf.math.multiply_auc: 0.9231
# Epoch 77/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0765 - ctr_output_loss: 0.5351 - tf.math.multiply_loss: 0.5293 - ctr_output_binary_crossentropy: 0.5351 - ctr_output_auc: 0.8511 - tf.math.multiply_binary_crossentropy: 0.5293 - tf.math.multiply_auc: 0.9019 - val_loss: 1.0301 - val_ctr_output_loss: 0.5222 - val_tf.math.multiply_loss: 0.4957 - val_ctr_output_binary_crossentropy: 0.5222 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4957 - val_tf.math.multiply_auc: 0.9230
# Epoch 78/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0754 - ctr_output_loss: 0.5334 - tf.math.multiply_loss: 0.5298 - ctr_output_binary_crossentropy: 0.5334 - ctr_output_auc: 0.8514 - tf.math.multiply_binary_crossentropy: 0.5298 - tf.math.multiply_auc: 0.9028 - val_loss: 1.0301 - val_ctr_output_loss: 0.5259 - val_tf.math.multiply_loss: 0.4922 - val_ctr_output_binary_crossentropy: 0.5259 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4922 - val_tf.math.multiply_auc: 0.9232
# Epoch 79/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0749 - ctr_output_loss: 0.5354 - tf.math.multiply_loss: 0.5275 - ctr_output_binary_crossentropy: 0.5354 - ctr_output_auc: 0.8510 - tf.math.multiply_binary_crossentropy: 0.5275 - tf.math.multiply_auc: 0.9022 - val_loss: 1.0298 - val_ctr_output_loss: 0.5207 - val_tf.math.multiply_loss: 0.4970 - val_ctr_output_binary_crossentropy: 0.5207 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4970 - val_tf.math.multiply_auc: 0.9236
# Epoch 80/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0753 - ctr_output_loss: 0.5324 - tf.math.multiply_loss: 0.5308 - ctr_output_binary_crossentropy: 0.5324 - ctr_output_auc: 0.8500 - tf.math.multiply_binary_crossentropy: 0.5308 - tf.math.multiply_auc: 0.9034 - val_loss: 1.0299 - val_ctr_output_loss: 0.5225 - val_tf.math.multiply_loss: 0.4954 - val_ctr_output_binary_crossentropy: 0.5225 - val_ctr_output_auc: 0.8756 - val_tf.math.multiply_binary_crossentropy: 0.4954 - val_tf.math.multiply_auc: 0.9238
# Epoch 81/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0729 - ctr_output_loss: 0.5361 - tf.math.multiply_loss: 0.5248 - ctr_output_binary_crossentropy: 0.5361 - ctr_output_auc: 0.8517 - tf.math.multiply_binary_crossentropy: 0.5248 - tf.math.multiply_auc: 0.9041 - val_loss: 1.0298 - val_ctr_output_loss: 0.5239 - val_tf.math.multiply_loss: 0.4939 - val_ctr_output_binary_crossentropy: 0.5239 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4939 - val_tf.math.multiply_auc: 0.9232
# Epoch 82/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0770 - ctr_output_loss: 0.5331 - tf.math.multiply_loss: 0.5318 - ctr_output_binary_crossentropy: 0.5331 - ctr_output_auc: 0.8502 - tf.math.multiply_binary_crossentropy: 0.5318 - tf.math.multiply_auc: 0.9015 - val_loss: 1.0298 - val_ctr_output_loss: 0.5243 - val_tf.math.multiply_loss: 0.4935 - val_ctr_output_binary_crossentropy: 0.5243 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4935 - val_tf.math.multiply_auc: 0.9233
# Epoch 83/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0774 - ctr_output_loss: 0.5403 - tf.math.multiply_loss: 0.5251 - ctr_output_binary_crossentropy: 0.5403 - ctr_output_auc: 0.8484 - tf.math.multiply_binary_crossentropy: 0.5251 - tf.math.multiply_auc: 0.9026 - val_loss: 1.0298 - val_ctr_output_loss: 0.5215 - val_tf.math.multiply_loss: 0.4963 - val_ctr_output_binary_crossentropy: 0.5215 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.4963 - val_tf.math.multiply_auc: 0.9236
# Epoch 84/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0746 - ctr_output_loss: 0.5292 - tf.math.multiply_loss: 0.5334 - ctr_output_binary_crossentropy: 0.5292 - ctr_output_auc: 0.8503 - tf.math.multiply_binary_crossentropy: 0.5334 - tf.math.multiply_auc: 0.9040 - val_loss: 1.0300 - val_ctr_output_loss: 0.5248 - val_tf.math.multiply_loss: 0.4932 - val_ctr_output_binary_crossentropy: 0.5248 - val_ctr_output_auc: 0.8756 - val_tf.math.multiply_binary_crossentropy: 0.4932 - val_tf.math.multiply_auc: 0.9236
# Epoch 85/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0732 - ctr_output_loss: 0.5372 - tf.math.multiply_loss: 0.5240 - ctr_output_binary_crossentropy: 0.5372 - ctr_output_auc: 0.8504 - tf.math.multiply_binary_crossentropy: 0.5240 - tf.math.multiply_auc: 0.9050 - val_loss: 1.0297 - val_ctr_output_loss: 0.5215 - val_tf.math.multiply_loss: 0.4962 - val_ctr_output_binary_crossentropy: 0.5215 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.4962 - val_tf.math.multiply_auc: 0.9235
# Epoch 86/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0743 - ctr_output_loss: 0.5352 - tf.math.multiply_loss: 0.5271 - ctr_output_binary_crossentropy: 0.5352 - ctr_output_auc: 0.8518 - tf.math.multiply_binary_crossentropy: 0.5271 - tf.math.multiply_auc: 0.9029 - val_loss: 1.0296 - val_ctr_output_loss: 0.5205 - val_tf.math.multiply_loss: 0.4971 - val_ctr_output_binary_crossentropy: 0.5205 - val_ctr_output_auc: 0.8762 - val_tf.math.multiply_binary_crossentropy: 0.4971 - val_tf.math.multiply_auc: 0.9233
# Epoch 87/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0742 - ctr_output_loss: 0.5334 - tf.math.multiply_loss: 0.5288 - ctr_output_binary_crossentropy: 0.5334 - ctr_output_auc: 0.8509 - tf.math.multiply_binary_crossentropy: 0.5288 - tf.math.multiply_auc: 0.9033 - val_loss: 1.0295 - val_ctr_output_loss: 0.5258 - val_tf.math.multiply_loss: 0.4918 - val_ctr_output_binary_crossentropy: 0.5258 - val_ctr_output_auc: 0.8764 - val_tf.math.multiply_binary_crossentropy: 0.4918 - val_tf.math.multiply_auc: 0.9232
# Epoch 88/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0784 - ctr_output_loss: 0.5369 - tf.math.multiply_loss: 0.5296 - ctr_output_binary_crossentropy: 0.5369 - ctr_output_auc: 0.8476 - tf.math.multiply_binary_crossentropy: 0.5296 - tf.math.multiply_auc: 0.9019 - val_loss: 1.0297 - val_ctr_output_loss: 0.5211 - val_tf.math.multiply_loss: 0.4967 - val_ctr_output_binary_crossentropy: 0.5211 - val_ctr_output_auc: 0.8756 - val_tf.math.multiply_binary_crossentropy: 0.4967 - val_tf.math.multiply_auc: 0.9241
# Epoch 89/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0761 - ctr_output_loss: 0.5354 - tf.math.multiply_loss: 0.5289 - ctr_output_binary_crossentropy: 0.5354 - ctr_output_auc: 0.8482 - tf.math.multiply_binary_crossentropy: 0.5289 - tf.math.multiply_auc: 0.9039 - val_loss: 1.0298 - val_ctr_output_loss: 0.5250 - val_tf.math.multiply_loss: 0.4929 - val_ctr_output_binary_crossentropy: 0.5250 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.4929 - val_tf.math.multiply_auc: 0.9235
# Epoch 90/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0748 - ctr_output_loss: 0.5349 - tf.math.multiply_loss: 0.5281 - ctr_output_binary_crossentropy: 0.5349 - ctr_output_auc: 0.8526 - tf.math.multiply_binary_crossentropy: 0.5281 - tf.math.multiply_auc: 0.9012 - val_loss: 1.0296 - val_ctr_output_loss: 0.5251 - val_tf.math.multiply_loss: 0.4926 - val_ctr_output_binary_crossentropy: 0.5251 - val_ctr_output_auc: 0.8763 - val_tf.math.multiply_binary_crossentropy: 0.4926 - val_tf.math.multiply_auc: 0.9230
# Epoch 91/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0758 - ctr_output_loss: 0.5356 - tf.math.multiply_loss: 0.5283 - ctr_output_binary_crossentropy: 0.5356 - ctr_output_auc: 0.8497 - tf.math.multiply_binary_crossentropy: 0.5283 - tf.math.multiply_auc: 0.9023 - val_loss: 1.0296 - val_ctr_output_loss: 0.5210 - val_tf.math.multiply_loss: 0.4967 - val_ctr_output_binary_crossentropy: 0.5210 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.4967 - val_tf.math.multiply_auc: 0.9236
# Epoch 92/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0754 - ctr_output_loss: 0.5345 - tf.math.multiply_loss: 0.5292 - ctr_output_binary_crossentropy: 0.5345 - ctr_output_auc: 0.8502 - tf.math.multiply_binary_crossentropy: 0.5292 - tf.math.multiply_auc: 0.9029 - val_loss: 1.0294 - val_ctr_output_loss: 0.5240 - val_tf.math.multiply_loss: 0.4937 - val_ctr_output_binary_crossentropy: 0.5240 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.4937 - val_tf.math.multiply_auc: 0.9233
# Epoch 93/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0769 - ctr_output_loss: 0.5382 - tf.math.multiply_loss: 0.5269 - ctr_output_binary_crossentropy: 0.5382 - ctr_output_auc: 0.8495 - tf.math.multiply_binary_crossentropy: 0.5269 - tf.math.multiply_auc: 0.9021 - val_loss: 1.0294 - val_ctr_output_loss: 0.5180 - val_tf.math.multiply_loss: 0.4997 - val_ctr_output_binary_crossentropy: 0.5180 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.4997 - val_tf.math.multiply_auc: 0.9236
# Epoch 94/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0740 - ctr_output_loss: 0.5303 - tf.math.multiply_loss: 0.5319 - ctr_output_binary_crossentropy: 0.5303 - ctr_output_auc: 0.8506 - tf.math.multiply_binary_crossentropy: 0.5319 - tf.math.multiply_auc: 0.9042 - val_loss: 1.0292 - val_ctr_output_loss: 0.5260 - val_tf.math.multiply_loss: 0.4914 - val_ctr_output_binary_crossentropy: 0.5260 - val_ctr_output_auc: 0.8761 - val_tf.math.multiply_binary_crossentropy: 0.4914 - val_tf.math.multiply_auc: 0.9232
# Epoch 95/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0759 - ctr_output_loss: 0.5370 - tf.math.multiply_loss: 0.5271 - ctr_output_binary_crossentropy: 0.5370 - ctr_output_auc: 0.8507 - tf.math.multiply_binary_crossentropy: 0.5271 - tf.math.multiply_auc: 0.9015 - val_loss: 1.0292 - val_ctr_output_loss: 0.5216 - val_tf.math.multiply_loss: 0.4959 - val_ctr_output_binary_crossentropy: 0.5216 - val_ctr_output_auc: 0.8760 - val_tf.math.multiply_binary_crossentropy: 0.4959 - val_tf.math.multiply_auc: 0.9236
# Epoch 96/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0738 - ctr_output_loss: 0.5339 - tf.math.multiply_loss: 0.5281 - ctr_output_binary_crossentropy: 0.5339 - ctr_output_auc: 0.8512 - tf.math.multiply_binary_crossentropy: 0.5281 - tf.math.multiply_auc: 0.9043 - val_loss: 1.0292 - val_ctr_output_loss: 0.5255 - val_tf.math.multiply_loss: 0.4919 - val_ctr_output_binary_crossentropy: 0.5255 - val_ctr_output_auc: 0.8763 - val_tf.math.multiply_binary_crossentropy: 0.4919 - val_tf.math.multiply_auc: 0.9231
# Epoch 97/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0738 - ctr_output_loss: 0.5343 - tf.math.multiply_loss: 0.5278 - ctr_output_binary_crossentropy: 0.5343 - ctr_output_auc: 0.8513 - tf.math.multiply_binary_crossentropy: 0.5278 - tf.math.multiply_auc: 0.9030 - val_loss: 1.0291 - val_ctr_output_loss: 0.5231 - val_tf.math.multiply_loss: 0.4943 - val_ctr_output_binary_crossentropy: 0.5231 - val_ctr_output_auc: 0.8759 - val_tf.math.multiply_binary_crossentropy: 0.4943 - val_tf.math.multiply_auc: 0.9238
# Epoch 98/100
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0744 - ctr_output_loss: 0.5340 - tf.math.multiply_loss: 0.5286 - ctr_output_binary_crossentropy: 0.5340 - ctr_output_auc: 0.8506 - tf.math.multiply_binary_crossentropy: 0.5286 - tf.math.multiply_auc: 0.9032 - val_loss: 1.0290 - val_ctr_output_loss: 0.5243 - val_tf.math.multiply_loss: 0.4930 - val_ctr_output_binary_crossentropy: 0.5243 - val_ctr_output_auc: 0.8763 - val_tf.math.multiply_binary_crossentropy: 0.4930 - val_tf.math.multiply_auc: 0.9233
# Epoch 99/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0773 - ctr_output_loss: 0.5373 - tf.math.multiply_loss: 0.5283 - ctr_output_binary_crossentropy: 0.5373 - ctr_output_auc: 0.8501 - tf.math.multiply_binary_crossentropy: 0.5283 - tf.math.multiply_auc: 0.9006 - val_loss: 1.0292 - val_ctr_output_loss: 0.5225 - val_tf.math.multiply_loss: 0.4951 - val_ctr_output_binary_crossentropy: 0.5225 - val_ctr_output_auc: 0.8757 - val_tf.math.multiply_binary_crossentropy: 0.4951 - val_tf.math.multiply_auc: 0.9240
# Epoch 100/100
# 26/26 [==============================] - 0s 5ms/step - loss: 1.0753 - ctr_output_loss: 0.5340 - tf.math.multiply_loss: 0.5297 - ctr_output_binary_crossentropy: 0.5340 - ctr_output_auc: 0.8493 - tf.math.multiply_binary_crossentropy: 0.5297 - tf.math.multiply_auc: 0.9036 - val_loss: 1.0295 - val_ctr_output_loss: 0.5223 - val_tf.math.multiply_loss: 0.4956 - val_ctr_output_binary_crossentropy: 0.5223 - val_ctr_output_auc: 0.8758 - val_tf.math.multiply_binary_crossentropy: 0.4956 - val_tf.math.multiply_auc: 0.9235

# %%
# 模型预测与评估
result = model.predict(test_input)

for idx, target_name in enumerate(tasks):
    print(idx, target_name)
    model_metric(np.array([i[0] for i in result[idx]]), test_df[target_name].values)
# Out:
# 0 income_50k
# 模型准确率:0.7185676555494134, AUC得分:0.8712877007239518, LogLoss:0.5233858462358333
#               precision    recall  f1-score   support
#
#            0       0.94      0.67      0.78     12435
#            1       0.45      0.87      0.59      3846
#
#     accuracy                           0.72     16281
#    macro avg       0.70      0.77      0.69     16281
# weighted avg       0.83      0.72      0.74     16281
#
# ==========================================================
# 1 marital_status
# 模型准确率:0.7853940175664885, AUC得分:0.9182682785716367, LogLoss:0.5038989764330436
#               precision    recall  f1-score   support
#
#            0       0.61      0.99      0.76      5434
#            1       0.99      0.68      0.81     10847
#
#     accuracy                           0.79     16281
#    macro avg       0.80      0.84      0.78     16281
# weighted avg       0.87      0.79      0.79     16281
#
# ==========================================================
