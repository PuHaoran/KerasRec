# %%
import os
import numpy as np
import pandas as pd
from collections import namedtuple

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.python.keras.callbacks import EarlyStopping
from sklearn.preprocessing import  MinMaxScaler, LabelEncoder

from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.metrics import classification_report, roc_curve

# %% [markdown]
# ##### 获取数据

# %%
def get_criteo_data():
    """ 读取criteo数据集 """
    train_path = '../data/criteo/train.txt'
    test_path = '../data/criteo/test.txt'

    dense_column_names = ['I' + str(i) for i in range(1, 14)]
    sparse_column_names = ['C' + str(i) for i in range(14, 40)]
    column_names = ['label'] + dense_column_names + sparse_column_names

    train_df = pd.read_csv(train_path, names=column_names, sep='\t')
    test_df = pd.read_csv(test_path, names=column_names, sep='\t')
    return train_df, test_df, dense_column_names, sparse_column_names

train_df, test_df, dense_column_names, sparse_column_names = get_criteo_data()
print('train.shape: {}, test.shape: {}'.format(train_df.shape, test_df.shape))
# Out:
# train.shape: (1000000, 40), test.shape: (1000000, 40)

# %% [markdown]
# ##### 数据预处理

# %%
data = pd.concat([train_df, test_df], axis=0)

def data_processing(df, dense_column_names, sparse_column_names):
    """ 数据预处理 """
    df[dense_column_names] = df[dense_column_names].fillna(0.0)
    for f in dense_column_names:
        df[f] = df[f].apply(lambda x: np.log(x+1) if x > -1 else -1)
    
    df[sparse_column_names] = df[sparse_column_names].fillna("-1")
    for f in sparse_column_names:
        lbe = LabelEncoder()
        df[f] = lbe.fit_transform(df[f])
    return df[dense_column_names + sparse_column_names]

df = data_processing(data, dense_column_names, sparse_column_names)
df['label'] = data['label']

train_df, test_df = df.iloc[0:train_df.shape[0]], df.iloc[train_df.shape[0]:]
print('train.shape:{}, test.shape:{}'.format(train_df.shape, test_df.shape))
# Out:
# train.shape:(1000000, 40), test.shape:(1000000, 40)

# %% [markdown]
# ##### 模型构建
#
# 如何提取FM模型预训练参数？
#
# 从原有模型结构中取出部分模型结构作为获取预训练参数的模型。
#
# 1. 构建一个完整的FM模型。
# 2. 选取所需的部分或全部特征对应的Input张量列表作为输入和某一层对应的张量/张量列表作为输出，形如：
#
# - spare_embed_model = Model(inputs=sparse_input_list, outputs=concat_sparse_kd_embed_list)
#
# 3. 通过构建的新模型进行预测，输入是Input所对应特征，输出是outputs相应层所对应的输出数据，形如：
#
# - spare_embed_model_input = {f: test[f] for f in sparse_column_names}
# - spare_embedding = spare_embed_model.predict(spare_embed_model_input, batch_size=2**12)
#
# 自定义层（继承Layer父类）
#
# - call函数中可以直接使用低级API，但如果需要使用层的API（例如:Dense、Dropout等），则需要先在build函数中定义然后在build中调用。
#
# ##### 第一阶段：训练FM模型，获取稀疏特征对应的embedding向量。

# %%
SparseFeature = namedtuple('SparseFeature', ['name', 'vocabulary_size', 'embedding_size'])
DenseFeature = namedtuple('DenseFeature', ['name', 'dimension'])

feature_columns = [SparseFeature(f, vocabulary_size=df[f].nunique(), embedding_size=4) for f in sparse_column_names] + \
[DenseFeature(f, 1) for f in dense_column_names]
feature_columns
# Out:
# [SparseFeature(name='C14', vocabulary_size=1370, embedding_size=4),
#  SparseFeature(name='C15', vocabulary_size=541, embedding_size=4),
#  SparseFeature(name='C16', vocabulary_size=597026, embedding_size=4),
#  SparseFeature(name='C17', vocabulary_size=200785, embedding_size=4),
#  SparseFeature(name='C18', vocabulary_size=284, embedding_size=4),
#  SparseFeature(name='C19', vocabulary_size=17, embedding_size=4),
#  SparseFeature(name='C20', vocabulary_size=11387, embedding_size=4),
#  SparseFeature(name='C21', vocabulary_size=600, embedding_size=4),
#  SparseFeature(name='C22', vocabulary_size=3, embedding_size=4),
#  SparseFeature(name='C23', vocabulary_size=39665, embedding_size=4),
#  SparseFeature(name='C24', vocabulary_size=4953, embedding_size=4),
#  SparseFeature(name='C25', vocabulary_size=498707, embedding_size=4),
#  SparseFeature(name='C26', vocabulary_size=3097, embedding_size=4),
#  SparseFeature(name='C27', vocabulary_size=26, embedding_size=4),
#  SparseFeature(name='C28', vocabulary_size=10159, embedding_size=4),
#  SparseFeature(name='C29', vocabulary_size=371933, embedding_size=4),
#  SparseFeature(name='C30', vocabulary_size=10, embedding_size=4),
#  SparseFeature(name='C31', vocabulary_size=4256, embedding_size=4),
#  SparseFeature(name='C32', vocabulary_size=1957, embedding_size=4),
#  SparseFeature(name='C33', vocabulary_size=4, embedding_size=4),
#  SparseFeature(name='C34', vocabulary_size=443312, embedding_size=4),
#  SparseFeature(name='C35', vocabulary_size=17, embedding_size=4),
#  SparseFeature(name='C36', vocabulary_size=15, embedding_size=4),
#  SparseFeature(name='C37', vocabulary_size=59876, embedding_size=4),
#  SparseFeature(name='C38', vocabulary_size=81, embedding_size=4),
#  SparseFeature(name='C39', vocabulary_size=43274, embedding_size=4),
#  DenseFeature(name='I1', dimension=1),
#  DenseFeature(name='I2', dimension=1),
#  DenseFeature(name='I3', dimension=1),
#  DenseFeature(name='I4', dimension=1),
#  DenseFeature(name='I5', dimension=1),
#  DenseFeature(name='I6', dimension=1),
#  DenseFeature(name='I7', dimension=1),
#  DenseFeature(name='I8', dimension=1),
#  DenseFeature(name='I9', dimension=1),
#  DenseFeature(name='I10', dimension=1),
#  DenseFeature(name='I11', dimension=1),
#  DenseFeature(name='I12', dimension=1),
#  DenseFeature(name='I13', dimension=1)]

# %%
class FM_Layer(Layer):
    def __init__(self):
        super(FM_Layer, self).__init__()
        
    def call(self, inputs):
        concat_embed_values = inputs
        print('concat_embed_values.shape: ', concat_embed_values.shape) # (None, 26, 4)
        sum_square = tf.square(tf.reduce_sum(concat_embed_values, axis=1, keepdims=True)) # (None, 1, 4)
        print('sum_square.shape: ', sum_square.shape)
        square_sum = tf.reduce_sum(concat_embed_values * concat_embed_values, axis=1, keepdims=True) # (None, 1, 4)
        print('square_sum.shape: ', square_sum.shape)
        output = sum_square - square_sum # 和的平方-平方的和
        output = 0.5 * tf.reduce_sum(output, axis=2, keepdims=False) # (None 1)
        print('output.shape: ', output.shape)
        return output
    
    def compute_output_shape(self, input_shape):
        return (None, 1)
    
def model_metric(prob, label, thr=0.5):
    """ 模型评估 """
    # AUC
    fpr, tpr, threshold = metrics.roc_curve(label, prob)
    auc = metrics.auc(fpr, tpr)
    score = metrics.accuracy_score(label, prob > thr)
    # LogLoss
    logloss = log_loss(label, prob)
    print('模型准确率:{}, AUC得分:{}, LogLoss:{}'.format(score, auc, logloss))
    print(classification_report(label, prob > thr, digits=2))
    print('==========================================================')

def build_input_layers(feature_columns):
    """ 构建输入层 """
    dense_input_dict, sparse_input_dict = {}, {}
    for f in feature_columns:
        if isinstance(f, DenseFeature):
            dense_input_dict[f.name] = Input(shape=(f.dimension, ), name=f.name)
        elif isinstance(f, SparseFeature):
            sparse_input_dict[f.name] = Input(shape=(1, ), name=f.name)
    return dense_input_dict, sparse_input_dict
    
def build_embedding_layers(feature_columns, is_linear):
    """ 构建embedding层 """
    embedding_layer_dict = {}
    sparse_feature_columns = list(filter(lambda x: isinstance(x, SparseFeature), feature_columns))
    if is_linear:
        for f in sparse_feature_columns:
            embedding_layer_dict[f.name] = Embedding(f.vocabulary_size+1, 1, name='1d_emb_' + f.name)
    else:
        for f in sparse_feature_columns:
            embedding_layer_dict[f.name] = Embedding(f.vocabulary_size+1, f.embedding_size, name='kd_emb_' + f.name)
    return embedding_layer_dict
    
def get_linear_logits(dense_input_dict, sparse_input_dict, feature_columns):
    """ 数值特征拼接一起传入全连接层 + 类别特征onehot，flatten，add """
    concat_dense_inputs = Concatenate(axis=1)(list(dense_input_dict.values()))
    dense_logits_output = Dense(1)(concat_dense_inputs)
    
    sparse_feature_columns = list(filter(lambda x: isinstance(x, SparseFeature), feature_columns))
    embedding_layer_dict = build_embedding_layers(feature_columns, is_linear=True)
    
    # embedding(input)查表操作，返回对应input的嵌入向量
    sparse_1d_embed_list = []
    for f in sparse_feature_columns:
        _input = sparse_input_dict[f.name]
        _embed = Flatten()(embedding_layer_dict[f.name](_input))
        sparse_1d_embed_list.append(_embed)
    
    sparse_logits_output = Add()(sparse_1d_embed_list)
    linear_logits = Add()([dense_logits_output, sparse_logits_output])
    return linear_logits
    
def get_fm_logits(sparse_input_dict, kd_embedding_layer_dict, feature_columns):
    """ 取出input所对应的嵌入向量拼接在一起，计算和的平和-平方的和 """
    sparse_feature_columns = list(filter(lambda x: isinstance(x, SparseFeature), feature_columns))
    sparse_kd_embed_list = []
    for f in sparse_feature_columns:
        _input = sparse_input_dict[f.name]
        _embed = kd_embedding_layer_dict[f.name](_input)
        sparse_kd_embed_list.append(_embed)
    
    concat_sparse_kd_embed_list = Concatenate(axis=1)(sparse_kd_embed_list)
    
    fm_logits = FM_Layer()(concat_sparse_kd_embed_list)
    return fm_logits, concat_sparse_kd_embed_list
    
def FM(feature_columns, seed=1024, l2_reg=1e-5, task='binary'):
    """ Instantiates FM architecture
    :param feature_columns 
    :param seed
    :param l2_reg L2regularization
    :return: A kears model instance
    """
    dense_input_dict, sparse_input_dict = build_input_layers(feature_columns)
    input_list = list(dense_input_dict.values()) + list(sparse_input_dict.values())
    
    # w * x
    linear_logits = get_linear_logits(dense_input_dict, sparse_input_dict, feature_columns)
    
    # 0.5 * [sum(vixi)**2 - sum(vixi*vixi)
    kd_embedding_layer_dict = build_embedding_layers(feature_columns, is_linear=False)
    fm_logits, concat_sparse_kd_embed_list = get_fm_logits(sparse_input_dict, kd_embedding_layer_dict, feature_columns)
    
    output_logits = Add()([linear_logits, fm_logits])
    output_layer = Activation("sigmoid")(output_logits)
    model = Model(input_list, output_layer)
    
    # 获取稀疏特征对应的embedding向量
    sparse_input_list = list(sparse_input_dict.values())
    flatten_sparse_kd_embed_list = Flatten()(concat_sparse_kd_embed_list)
    model.__setattr__("sparse_input", sparse_input_list)
    model.__setattr__("spare_embedding", flatten_sparse_kd_embed_list)

    spare_embed_model = Model(inputs=model.sparse_input, outputs=model.spare_embedding)
    #spare_embed_model = Model(inputs=sparse_input_list, outputs=flatten_sparse_kd_embed_list)
    return model, spare_embed_model

model, spare_embed_model = FM(feature_columns)
model.summary()
# Out:
# concat_embed_values.shape:  (None, 26, 4)
# sum_square.shape:  (None, 1, 4)
# square_sum.shape:  (None, 1, 4)
# output.shape:  (None, 1)
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# C14 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C15 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C16 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C17 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C18 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C19 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C20 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C21 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C22 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C23 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C24 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C25 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C26 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C27 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C28 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C29 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C30 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C31 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C32 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C33 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C34 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C35 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C36 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C37 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C38 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C39 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I1 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I2 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I3 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I4 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I5 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I6 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I7 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I8 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I9 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I10 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I11 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I12 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I13 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# 1d_emb_C14 (Embedding)          (None, 1, 1)         1371        C14[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C15 (Embedding)          (None, 1, 1)         542         C15[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C16 (Embedding)          (None, 1, 1)         597027      C16[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C17 (Embedding)          (None, 1, 1)         200786      C17[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C18 (Embedding)          (None, 1, 1)         285         C18[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C19 (Embedding)          (None, 1, 1)         18          C19[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C20 (Embedding)          (None, 1, 1)         11388       C20[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C21 (Embedding)          (None, 1, 1)         601         C21[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C22 (Embedding)          (None, 1, 1)         4           C22[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C23 (Embedding)          (None, 1, 1)         39666       C23[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C24 (Embedding)          (None, 1, 1)         4954        C24[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C25 (Embedding)          (None, 1, 1)         498708      C25[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C26 (Embedding)          (None, 1, 1)         3098        C26[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C27 (Embedding)          (None, 1, 1)         27          C27[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C28 (Embedding)          (None, 1, 1)         10160       C28[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C29 (Embedding)          (None, 1, 1)         371934      C29[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C30 (Embedding)          (None, 1, 1)         11          C30[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C31 (Embedding)          (None, 1, 1)         4257        C31[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C32 (Embedding)          (None, 1, 1)         1958        C32[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C33 (Embedding)          (None, 1, 1)         5           C33[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C34 (Embedding)          (None, 1, 1)         443313      C34[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C35 (Embedding)          (None, 1, 1)         18          C35[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C36 (Embedding)          (None, 1, 1)         16          C36[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C37 (Embedding)          (None, 1, 1)         59877       C37[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C38 (Embedding)          (None, 1, 1)         82          C38[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C39 (Embedding)          (None, 1, 1)         43275       C39[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 13)           0           I1[0][0]
#                                                                  I2[0][0]
#                                                                  I3[0][0]
#                                                                  I4[0][0]
#                                                                  I5[0][0]
#                                                                  I6[0][0]
#                                                                  I7[0][0]
#                                                                  I8[0][0]
#                                                                  I9[0][0]
#                                                                  I10[0][0]
#                                                                  I11[0][0]
#                                                                  I12[0][0]
#                                                                  I13[0][0]
# __________________________________________________________________________________________________
# flatten_27 (Flatten)            (None, 1)            0           1d_emb_C14[0][0]
# __________________________________________________________________________________________________
# flatten_28 (Flatten)            (None, 1)            0           1d_emb_C15[0][0]
# __________________________________________________________________________________________________
# flatten_29 (Flatten)            (None, 1)            0           1d_emb_C16[0][0]
# __________________________________________________________________________________________________
# flatten_30 (Flatten)            (None, 1)            0           1d_emb_C17[0][0]
# __________________________________________________________________________________________________
# flatten_31 (Flatten)            (None, 1)            0           1d_emb_C18[0][0]
# __________________________________________________________________________________________________
# flatten_32 (Flatten)            (None, 1)            0           1d_emb_C19[0][0]
# __________________________________________________________________________________________________
# flatten_33 (Flatten)            (None, 1)            0           1d_emb_C20[0][0]
# __________________________________________________________________________________________________
# flatten_34 (Flatten)            (None, 1)            0           1d_emb_C21[0][0]
# __________________________________________________________________________________________________
# flatten_35 (Flatten)            (None, 1)            0           1d_emb_C22[0][0]
# __________________________________________________________________________________________________
# flatten_36 (Flatten)            (None, 1)            0           1d_emb_C23[0][0]
# __________________________________________________________________________________________________
# flatten_37 (Flatten)            (None, 1)            0           1d_emb_C24[0][0]
# __________________________________________________________________________________________________
# flatten_38 (Flatten)            (None, 1)            0           1d_emb_C25[0][0]
# __________________________________________________________________________________________________
# flatten_39 (Flatten)            (None, 1)            0           1d_emb_C26[0][0]
# __________________________________________________________________________________________________
# flatten_40 (Flatten)            (None, 1)            0           1d_emb_C27[0][0]
# __________________________________________________________________________________________________
# flatten_41 (Flatten)            (None, 1)            0           1d_emb_C28[0][0]
# __________________________________________________________________________________________________
# flatten_42 (Flatten)            (None, 1)            0           1d_emb_C29[0][0]
# __________________________________________________________________________________________________
# flatten_43 (Flatten)            (None, 1)            0           1d_emb_C30[0][0]
# __________________________________________________________________________________________________
# flatten_44 (Flatten)            (None, 1)            0           1d_emb_C31[0][0]
# __________________________________________________________________________________________________
# flatten_45 (Flatten)            (None, 1)            0           1d_emb_C32[0][0]
# __________________________________________________________________________________________________
# flatten_46 (Flatten)            (None, 1)            0           1d_emb_C33[0][0]
# __________________________________________________________________________________________________
# flatten_47 (Flatten)            (None, 1)            0           1d_emb_C34[0][0]
# __________________________________________________________________________________________________
# flatten_48 (Flatten)            (None, 1)            0           1d_emb_C35[0][0]
# __________________________________________________________________________________________________
# flatten_49 (Flatten)            (None, 1)            0           1d_emb_C36[0][0]
# __________________________________________________________________________________________________
# flatten_50 (Flatten)            (None, 1)            0           1d_emb_C37[0][0]
# __________________________________________________________________________________________________
# flatten_51 (Flatten)            (None, 1)            0           1d_emb_C38[0][0]
# __________________________________________________________________________________________________
# flatten_52 (Flatten)            (None, 1)            0           1d_emb_C39[0][0]
# __________________________________________________________________________________________________
# kd_emb_C14 (Embedding)          (None, 1, 4)         5484        C14[0][0]
# __________________________________________________________________________________________________
# kd_emb_C15 (Embedding)          (None, 1, 4)         2168        C15[0][0]
# __________________________________________________________________________________________________
# kd_emb_C16 (Embedding)          (None, 1, 4)         2388108     C16[0][0]
# __________________________________________________________________________________________________
# kd_emb_C17 (Embedding)          (None, 1, 4)         803144      C17[0][0]
# __________________________________________________________________________________________________
# kd_emb_C18 (Embedding)          (None, 1, 4)         1140        C18[0][0]
# __________________________________________________________________________________________________
# kd_emb_C19 (Embedding)          (None, 1, 4)         72          C19[0][0]
# __________________________________________________________________________________________________
# kd_emb_C20 (Embedding)          (None, 1, 4)         45552       C20[0][0]
# __________________________________________________________________________________________________
# kd_emb_C21 (Embedding)          (None, 1, 4)         2404        C21[0][0]
# __________________________________________________________________________________________________
# kd_emb_C22 (Embedding)          (None, 1, 4)         16          C22[0][0]
# __________________________________________________________________________________________________
# kd_emb_C23 (Embedding)          (None, 1, 4)         158664      C23[0][0]
# __________________________________________________________________________________________________
# kd_emb_C24 (Embedding)          (None, 1, 4)         19816       C24[0][0]
# __________________________________________________________________________________________________
# kd_emb_C25 (Embedding)          (None, 1, 4)         1994832     C25[0][0]
# __________________________________________________________________________________________________
# kd_emb_C26 (Embedding)          (None, 1, 4)         12392       C26[0][0]
# __________________________________________________________________________________________________
# kd_emb_C27 (Embedding)          (None, 1, 4)         108         C27[0][0]
# __________________________________________________________________________________________________
# kd_emb_C28 (Embedding)          (None, 1, 4)         40640       C28[0][0]
# __________________________________________________________________________________________________
# kd_emb_C29 (Embedding)          (None, 1, 4)         1487736     C29[0][0]
# __________________________________________________________________________________________________
# kd_emb_C30 (Embedding)          (None, 1, 4)         44          C30[0][0]
# __________________________________________________________________________________________________
# kd_emb_C31 (Embedding)          (None, 1, 4)         17028       C31[0][0]
# __________________________________________________________________________________________________
# kd_emb_C32 (Embedding)          (None, 1, 4)         7832        C32[0][0]
# __________________________________________________________________________________________________
# kd_emb_C33 (Embedding)          (None, 1, 4)         20          C33[0][0]
# __________________________________________________________________________________________________
# kd_emb_C34 (Embedding)          (None, 1, 4)         1773252     C34[0][0]
# __________________________________________________________________________________________________
# kd_emb_C35 (Embedding)          (None, 1, 4)         72          C35[0][0]
# __________________________________________________________________________________________________
# kd_emb_C36 (Embedding)          (None, 1, 4)         64          C36[0][0]
# __________________________________________________________________________________________________
# kd_emb_C37 (Embedding)          (None, 1, 4)         239508      C37[0][0]
# __________________________________________________________________________________________________
# kd_emb_C38 (Embedding)          (None, 1, 4)         328         C38[0][0]
# __________________________________________________________________________________________________
# kd_emb_C39 (Embedding)          (None, 1, 4)         173100      C39[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            14          concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1)            0           flatten_27[0][0]
#                                                                  flatten_28[0][0]
#                                                                  flatten_29[0][0]
#                                                                  flatten_30[0][0]
#                                                                  flatten_31[0][0]
#                                                                  flatten_32[0][0]
#                                                                  flatten_33[0][0]
#                                                                  flatten_34[0][0]
#                                                                  flatten_35[0][0]
#                                                                  flatten_36[0][0]
#                                                                  flatten_37[0][0]
#                                                                  flatten_38[0][0]
#                                                                  flatten_39[0][0]
#                                                                  flatten_40[0][0]
#                                                                  flatten_41[0][0]
#                                                                  flatten_42[0][0]
#                                                                  flatten_43[0][0]
#                                                                  flatten_44[0][0]
#                                                                  flatten_45[0][0]
#                                                                  flatten_46[0][0]
#                                                                  flatten_47[0][0]
#                                                                  flatten_48[0][0]
#                                                                  flatten_49[0][0]
#                                                                  flatten_50[0][0]
#                                                                  flatten_51[0][0]
#                                                                  flatten_52[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 26, 4)        0           kd_emb_C14[0][0]
#                                                                  kd_emb_C15[0][0]
#                                                                  kd_emb_C16[0][0]
#                                                                  kd_emb_C17[0][0]
#                                                                  kd_emb_C18[0][0]
#                                                                  kd_emb_C19[0][0]
#                                                                  kd_emb_C20[0][0]
#                                                                  kd_emb_C21[0][0]
#                                                                  kd_emb_C22[0][0]
#                                                                  kd_emb_C23[0][0]
#                                                                  kd_emb_C24[0][0]
#                                                                  kd_emb_C25[0][0]
#                                                                  kd_emb_C26[0][0]
#                                                                  kd_emb_C27[0][0]
#                                                                  kd_emb_C28[0][0]
#                                                                  kd_emb_C29[0][0]
#                                                                  kd_emb_C30[0][0]
#                                                                  kd_emb_C31[0][0]
#                                                                  kd_emb_C32[0][0]
#                                                                  kd_emb_C33[0][0]
#                                                                  kd_emb_C34[0][0]
#                                                                  kd_emb_C35[0][0]
#                                                                  kd_emb_C36[0][0]
#                                                                  kd_emb_C37[0][0]
#                                                                  kd_emb_C38[0][0]
#                                                                  kd_emb_C39[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 1)            0           dense_1[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# fm__layer_1 (FM_Layer)          (None, 1)            0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1)            0           add_4[0][0]
#                                                                  fm__layer_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           add_5[0][0]
# ==================================================================================================
# Total params: 11,466,919
# Trainable params: 11,466,919
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 模型训练
train_input = {f: train_df[f] for f in dense_column_names + sparse_column_names}
test_input = {f: test_df[f] for f in dense_column_names + sparse_column_names}

my_callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, verbose=2, mode='auto')
]
model.compile('adam',
              loss='binary_crossentropy',
              metrics=["binary_crossentropy", tf.keras.metrics.AUC(name='auc')])
model.fit(train_input,
          train_df['label'].values,
          batch_size=1024,
          epochs=100,
          validation_split=0.2,
          callbacks=my_callbacks)
# Out:
# Epoch 1/100
# concat_embed_values.shape:  (None, 26, 4)
# sum_square.shape:  (None, 1, 4)
# square_sum.shape:  (None, 1, 4)
# output.shape:  (None, 1)
# concat_embed_values.shape:  (None, 26, 4)
# sum_square.shape:  (None, 1, 4)
# square_sum.shape:  (None, 1, 4)
# output.shape:  (None, 1)
# 782/782 [==============================] - ETA: 0s - loss: 0.5706 - binary_crossentropy: 0.5706 - auc: 0.6998concat_embed_values.shape:  (None, 26, 4)
# sum_square.shape:  (None, 1, 4)
# square_sum.shape:  (None, 1, 4)
# output.shape:  (None, 1)
# 782/782 [==============================] - 55s 65ms/step - loss: 0.5706 - binary_crossentropy: 0.5706 - auc: 0.6998 - val_loss: 0.4829 - val_binary_crossentropy: 0.4829 - val_auc: 0.7600
# Epoch 2/100
# 782/782 [==============================] - 51s 65ms/step - loss: 0.4307 - binary_crossentropy: 0.4307 - auc: 0.8216 - val_loss: 0.4766 - val_binary_crossentropy: 0.4766 - val_auc: 0.7677
# Epoch 3/100
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3814 - binary_crossentropy: 0.3814 - auc: 0.8656 - val_loss: 0.4926 - val_binary_crossentropy: 0.4926 - val_auc: 0.7577
# Epoch 4/100
# 782/782 [==============================] - 54s 69ms/step - loss: 0.3478 - binary_crossentropy: 0.3478 - auc: 0.8897 - val_loss: 0.5098 - val_binary_crossentropy: 0.5098 - val_auc: 0.7499
# Epoch 5/100
# 782/782 [==============================] - 55s 70ms/step - loss: 0.3270 - binary_crossentropy: 0.3270 - auc: 0.9026 - val_loss: 0.5235 - val_binary_crossentropy: 0.5235 - val_auc: 0.7442
# Epoch 6/100
# 782/782 [==============================] - 55s 71ms/step - loss: 0.3137 - binary_crossentropy: 0.3137 - auc: 0.9103 - val_loss: 0.5375 - val_binary_crossentropy: 0.5375 - val_auc: 0.7388
# Epoch 7/100
# 782/782 [==============================] - 54s 70ms/step - loss: 0.3042 - binary_crossentropy: 0.3042 - auc: 0.9155 - val_loss: 0.5462 - val_binary_crossentropy: 0.5462 - val_auc: 0.7355
# Epoch 8/100
# 782/782 [==============================] - 54s 69ms/step - loss: 0.2966 - binary_crossentropy: 0.2966 - auc: 0.9196 - val_loss: 0.5561 - val_binary_crossentropy: 0.5561 - val_auc: 0.7330
# Epoch 9/100
# 782/782 [==============================] - 55s 71ms/step - loss: 0.2905 - binary_crossentropy: 0.2905 - auc: 0.9228 - val_loss: 0.5647 - val_binary_crossentropy: 0.5647 - val_auc: 0.7313
# Epoch 10/100
# 782/782 [==============================] - 55s 70ms/step - loss: 0.2853 - binary_crossentropy: 0.2853 - auc: 0.9255 - val_loss: 0.5784 - val_binary_crossentropy: 0.5784 - val_auc: 0.7263
# Epoch 11/100
# 782/782 [==============================] - 54s 69ms/step - loss: 0.2805 - binary_crossentropy: 0.2805 - auc: 0.9279 - val_loss: 0.5807 - val_binary_crossentropy: 0.5807 - val_auc: 0.7264
# Epoch 12/100
# 782/782 [==============================] - 54s 69ms/step - loss: 0.2761 - binary_crossentropy: 0.2761 - auc: 0.9302 - val_loss: 0.5885 - val_binary_crossentropy: 0.5885 - val_auc: 0.7244
# Epoch 00012: early stopping

# %%
train_spare_embed_model_input = {f: train_df[f] for f in sparse_column_names}
train_spare_embedding = spare_embed_model.predict(train_spare_embed_model_input, batch_size=2**12)

test_spare_embed_model_input = {f: test_df[f] for f in sparse_column_names}
test_spare_embedding = spare_embed_model.predict(test_spare_embed_model_input, batch_size=2**12)
print(train_spare_embedding.shape, test_spare_embedding.shape)

for i in range(train_spare_embedding.shape[1]):
    train_df['emb{}'.format(i)] = train_spare_embedding[:, i]
    test_df['emb{}'.format(i)] = test_spare_embedding[:, i]
# Out:
# (1000000, 104) (1000000, 104)
# C:\SoftwareInstall\Anaconda\envs\py36\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\SoftwareInstall\Anaconda\envs\py36\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ##### 第二阶段：将所有样本的类别特征所提取出embedding向量和数值向量拼接在一起，输入到DNN模型中进行学习。

# %%
dnn_feature_columns = [DenseFeature(f, 1) for f in train_df.columns if f.startswith('I') or f.startswith('emb')]
dnn_feature_columns
# Out:
# [DenseFeature(name='I1', dimension=1),
#  DenseFeature(name='I2', dimension=1),
#  DenseFeature(name='I3', dimension=1),
#  DenseFeature(name='I4', dimension=1),
#  DenseFeature(name='I5', dimension=1),
#  DenseFeature(name='I6', dimension=1),
#  DenseFeature(name='I7', dimension=1),
#  DenseFeature(name='I8', dimension=1),
#  DenseFeature(name='I9', dimension=1),
#  DenseFeature(name='I10', dimension=1),
#  DenseFeature(name='I11', dimension=1),
#  DenseFeature(name='I12', dimension=1),
#  DenseFeature(name='I13', dimension=1),
#  DenseFeature(name='emb0', dimension=1),
#  DenseFeature(name='emb1', dimension=1),
#  DenseFeature(name='emb2', dimension=1),
#  DenseFeature(name='emb3', dimension=1),
#  DenseFeature(name='emb4', dimension=1),
#  DenseFeature(name='emb5', dimension=1),
#  DenseFeature(name='emb6', dimension=1),
#  DenseFeature(name='emb7', dimension=1),
#  DenseFeature(name='emb8', dimension=1),
#  DenseFeature(name='emb9', dimension=1),
#  DenseFeature(name='emb10', dimension=1),
#  DenseFeature(name='emb11', dimension=1),
#  DenseFeature(name='emb12', dimension=1),
#  DenseFeature(name='emb13', dimension=1),
#  DenseFeature(name='emb14', dimension=1),
#  DenseFeature(name='emb15', dimension=1),
#  DenseFeature(name='emb16', dimension=1),
#  DenseFeature(name='emb17', dimension=1),
#  DenseFeature(name='emb18', dimension=1),
#  DenseFeature(name='emb19', dimension=1),
#  DenseFeature(name='emb20', dimension=1),
#  DenseFeature(name='emb21', dimension=1),
#  DenseFeature(name='emb22', dimension=1),
#  DenseFeature(name='emb23', dimension=1),
#  DenseFeature(name='emb24', dimension=1),
#  DenseFeature(name='emb25', dimension=1),
#  DenseFeature(name='emb26', dimension=1),
#  DenseFeature(name='emb27', dimension=1),
#  DenseFeature(name='emb28', dimension=1),
#  DenseFeature(name='emb29', dimension=1),
#  DenseFeature(name='emb30', dimension=1),
#  DenseFeature(name='emb31', dimension=1),
#  DenseFeature(name='emb32', dimension=1),
#  DenseFeature(name='emb33', dimension=1),
#  DenseFeature(name='emb34', dimension=1),
#  DenseFeature(name='emb35', dimension=1),
#  DenseFeature(name='emb36', dimension=1),
#  DenseFeature(name='emb37', dimension=1),
#  DenseFeature(name='emb38', dimension=1),
#  DenseFeature(name='emb39', dimension=1),
#  DenseFeature(name='emb40', dimension=1),
#  DenseFeature(name='emb41', dimension=1),
#  DenseFeature(name='emb42', dimension=1),
#  DenseFeature(name='emb43', dimension=1),
#  DenseFeature(name='emb44', dimension=1),
#  DenseFeature(name='emb45', dimension=1),
#  DenseFeature(name='emb46', dimension=1),
#  DenseFeature(name='emb47', dimension=1),
#  DenseFeature(name='emb48', dimension=1),
#  DenseFeature(name='emb49', dimension=1),
#  DenseFeature(name='emb50', dimension=1),
#  DenseFeature(name='emb51', dimension=1),
#  DenseFeature(name='emb52', dimension=1),
#  DenseFeature(name='emb53', dimension=1),
#  DenseFeature(name='emb54', dimension=1),
#  DenseFeature(name='emb55', dimension=1),
#  DenseFeature(name='emb56', dimension=1),
#  DenseFeature(name='emb57', dimension=1),
#  DenseFeature(name='emb58', dimension=1),
#  DenseFeature(name='emb59', dimension=1),
#  DenseFeature(name='emb60', dimension=1),
#  DenseFeature(name='emb61', dimension=1),
#  DenseFeature(name='emb62', dimension=1),
#  DenseFeature(name='emb63', dimension=1),
#  DenseFeature(name='emb64', dimension=1),
#  DenseFeature(name='emb65', dimension=1),
#  DenseFeature(name='emb66', dimension=1),
#  DenseFeature(name='emb67', dimension=1),
#  DenseFeature(name='emb68', dimension=1),
#  DenseFeature(name='emb69', dimension=1),
#  DenseFeature(name='emb70', dimension=1),
#  DenseFeature(name='emb71', dimension=1),
#  DenseFeature(name='emb72', dimension=1),
#  DenseFeature(name='emb73', dimension=1),
#  DenseFeature(name='emb74', dimension=1),
#  DenseFeature(name='emb75', dimension=1),
#  DenseFeature(name='emb76', dimension=1),
#  DenseFeature(name='emb77', dimension=1),
#  DenseFeature(name='emb78', dimension=1),
#  DenseFeature(name='emb79', dimension=1),
#  DenseFeature(name='emb80', dimension=1),
#  DenseFeature(name='emb81', dimension=1),
#  DenseFeature(name='emb82', dimension=1),
#  DenseFeature(name='emb83', dimension=1),
#  DenseFeature(name='emb84', dimension=1),
#  DenseFeature(name='emb85', dimension=1),
#  DenseFeature(name='emb86', dimension=1),
#  DenseFeature(name='emb87', dimension=1),
#  DenseFeature(name='emb88', dimension=1),
#  DenseFeature(name='emb89', dimension=1),
#  DenseFeature(name='emb90', dimension=1),
#  DenseFeature(name='emb91', dimension=1),
#  DenseFeature(name='emb92', dimension=1),
#  DenseFeature(name='emb93', dimension=1),
#  DenseFeature(name='emb94', dimension=1),
#  DenseFeature(name='emb95', dimension=1),
#  DenseFeature(name='emb96', dimension=1),
#  DenseFeature(name='emb97', dimension=1),
#  DenseFeature(name='emb98', dimension=1),
#  DenseFeature(name='emb99', dimension=1),
#  DenseFeature(name='emb100', dimension=1),
#  DenseFeature(name='emb101', dimension=1),
#  DenseFeature(name='emb102', dimension=1),
#  DenseFeature(name='emb103', dimension=1)]

# %%
class DNN(Layer):
    """ Model子类化创建自定义模型 """
    def __init__(self):
        super(DNN, self).__init__()
        
    def build(self, input_shape):
        """ 定义权重 """
        self.dropout = Dropout(0.8)
        self.dense16 = Dense(16, activation='tanh')
        self.dense32 = Dense(32, activation='tanh')
        self.dense8 = Dense(8, activation='tanh')
        self.dense1 = Dense(1)
        self.activation = Activation("sigmoid")
        
    def call(self, inputs):
        """ 层的功能逻辑 """
        dnn_input = inputs
        
        dnn_out = self.dropout(self.dense16(dnn_input))
        dnn_out = self.dropout(self.dense32(dnn_out))
        dnn_out = self.dropout(self.dense8(dnn_out))
        dnn_out = self.dense1(dnn_out)
        #dnn_out = dnn_out)
        #dnn_out = self.dense8(inputs)
        #dnn_out = self.dropout(dnn_out)
        
        dnn_logits = self.activation(dnn_out)
        return dnn_logits
    
    def compute_output_shape(self, input_shape):
        return (None, 1)

dense_input_dict, _ = build_input_layers(dnn_feature_columns)
input_list = list(dense_input_dict.values())

concat_inputs = Concatenate(axis=1)(input_list)
output_layer = DNN()(concat_inputs)
dnn_model = Model(input_list, output_layer)
dnn_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# I1 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I2 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I3 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I4 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I5 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I6 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I7 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I8 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I9 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I10 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I11 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I12 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I13 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# emb0 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb1 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb2 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb3 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb4 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb5 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb6 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb7 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb8 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb9 (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# emb10 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb11 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb12 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb13 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb14 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb15 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb16 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb17 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb18 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb19 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb20 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb21 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb22 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb23 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb24 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb25 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb26 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb27 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb28 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb29 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb30 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb31 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb32 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb33 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb34 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb35 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb36 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb37 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb38 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb39 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb40 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb41 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb42 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb43 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb44 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb45 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb46 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb47 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb48 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb49 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb50 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb51 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb52 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb53 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb54 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb55 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb56 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb57 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb58 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb59 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb60 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb61 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb62 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb63 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb64 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb65 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb66 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb67 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb68 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb69 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb70 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb71 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb72 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb73 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb74 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb75 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb76 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb77 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb78 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb79 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb80 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb81 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb82 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb83 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb84 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb85 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb86 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb87 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb88 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb89 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb90 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb91 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb92 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb93 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb94 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb95 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb96 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb97 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb98 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb99 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# emb100 (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# emb101 (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# emb102 (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# emb103 (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 117)          0           I1[0][0]
#                                                                  I2[0][0]
#                                                                  I3[0][0]
#                                                                  I4[0][0]
#                                                                  I5[0][0]
#                                                                  I6[0][0]
#                                                                  I7[0][0]
#                                                                  I8[0][0]
#                                                                  I9[0][0]
#                                                                  I10[0][0]
#                                                                  I11[0][0]
#                                                                  I12[0][0]
#                                                                  I13[0][0]
#                                                                  emb0[0][0]
#                                                                  emb1[0][0]
#                                                                  emb2[0][0]
#                                                                  emb3[0][0]
#                                                                  emb4[0][0]
#                                                                  emb5[0][0]
#                                                                  emb6[0][0]
#                                                                  emb7[0][0]
#                                                                  emb8[0][0]
#                                                                  emb9[0][0]
#                                                                  emb10[0][0]
#                                                                  emb11[0][0]
#                                                                  emb12[0][0]
#                                                                  emb13[0][0]
#                                                                  emb14[0][0]
#                                                                  emb15[0][0]
#                                                                  emb16[0][0]
#                                                                  emb17[0][0]
#                                                                  emb18[0][0]
#                                                                  emb19[0][0]
#                                                                  emb20[0][0]
#                                                                  emb21[0][0]
#                                                                  emb22[0][0]
#                                                                  emb23[0][0]
#                                                                  emb24[0][0]
#                                                                  emb25[0][0]
#                                                                  emb26[0][0]
#                                                                  emb27[0][0]
#                                                                  emb28[0][0]
#                                                                  emb29[0][0]
#                                                                  emb30[0][0]
#                                                                  emb31[0][0]
#                                                                  emb32[0][0]
#                                                                  emb33[0][0]
#                                                                  emb34[0][0]
#                                                                  emb35[0][0]
#                                                                  emb36[0][0]
#                                                                  emb37[0][0]
#                                                                  emb38[0][0]
#                                                                  emb39[0][0]
#                                                                  emb40[0][0]
#                                                                  emb41[0][0]
#                                                                  emb42[0][0]
#                                                                  emb43[0][0]
#                                                                  emb44[0][0]
#                                                                  emb45[0][0]
#                                                                  emb46[0][0]
#                                                                  emb47[0][0]
#                                                                  emb48[0][0]
#                                                                  emb49[0][0]
#                                                                  emb50[0][0]
#                                                                  emb51[0][0]
#                                                                  emb52[0][0]
#                                                                  emb53[0][0]
#                                                                  emb54[0][0]
#                                                                  emb55[0][0]
#                                                                  emb56[0][0]
#                                                                  emb57[0][0]
#                                                                  emb58[0][0]
#                                                                  emb59[0][0]
#                                                                  emb60[0][0]
#                                                                  emb61[0][0]
#                                                                  emb62[0][0]
#                                                                  emb63[0][0]
#                                                                  emb64[0][0]
#                                                                  emb65[0][0]
#                                                                  emb66[0][0]
#                                                                  emb67[0][0]
#                                                                  emb68[0][0]
#                                                                  emb69[0][0]
#                                                                  emb70[0][0]
#                                                                  emb71[0][0]
#                                                                  emb72[0][0]
#                                                                  emb73[0][0]
#                                                                  emb74[0][0]
#                                                                  emb75[0][0]
#                                                                  emb76[0][0]
#                                                                  emb77[0][0]
#                                                                  emb78[0][0]
#                                                                  emb79[0][0]
#                                                                  emb80[0][0]
#                                                                  emb81[0][0]
#                                                                  emb82[0][0]
#                                                                  emb83[0][0]
#                                                                  emb84[0][0]
#                                                                  emb85[0][0]
#                                                                  emb86[0][0]
#                                                                  emb87[0][0]
#                                                                  emb88[0][0]
#                                                                  emb89[0][0]
#                                                                  emb90[0][0]
#                                                                  emb91[0][0]
#                                                                  emb92[0][0]
#                                                                  emb93[0][0]
#                                                                  emb94[0][0]
#                                                                  emb95[0][0]
#                                                                  emb96[0][0]
#                                                                  emb97[0][0]
#                                                                  emb98[0][0]
#                                                                  emb99[0][0]
#                                                                  emb100[0][0]
#                                                                  emb101[0][0]
#                                                                  emb102[0][0]
#                                                                  emb103[0][0]
# __________________________________________________________________________________________________
# dnn (DNN)                       (None, 1)            2705        concatenate_4[0][0]
# ==================================================================================================
# Total params: 2,705
# Trainable params: 2,705
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train_input = {f.name: train_df[f.name] for f in dnn_feature_columns}
test_input = {f.name: test_df[f.name] for f in dnn_feature_columns}

tf.config.run_functions_eagerly(True)
my_callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, verbose=2, mode='auto')
]
dnn_model.compile('adam',
              loss='binary_crossentropy',
              metrics=["binary_crossentropy", tf.keras.metrics.AUC(name='auc')])

dnn_model.fit(train_input,
          train_df['label'].values,
          batch_size=1024,
          epochs=100,
          validation_split=0.2,
          callbacks=my_callbacks)
# Out:
# C:\SoftwareInstall\Anaconda\envs\py36\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# Epoch 1/100
# 782/782 [==============================] - 25s 31ms/step - loss: 0.5544 - binary_crossentropy: 0.5544 - auc: 0.6812 - val_loss: 0.5516 - val_binary_crossentropy: 0.5516 - val_auc: 0.6992
# Epoch 2/100
# 782/782 [==============================] - 25s 32ms/step - loss: 0.4226 - binary_crossentropy: 0.4226 - auc: 0.8310 - val_loss: 0.5532 - val_binary_crossentropy: 0.5532 - val_auc: 0.6986
# Epoch 3/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.4032 - binary_crossentropy: 0.4032 - auc: 0.8487 - val_loss: 0.5529 - val_binary_crossentropy: 0.5529 - val_auc: 0.6949
# Epoch 4/100
# 782/782 [==============================] - 24s 30ms/step - loss: 0.3954 - binary_crossentropy: 0.3954 - auc: 0.8543 - val_loss: 0.5623 - val_binary_crossentropy: 0.5623 - val_auc: 0.6954
# Epoch 5/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.3942 - binary_crossentropy: 0.3942 - auc: 0.8553 - val_loss: 0.5666 - val_binary_crossentropy: 0.5666 - val_auc: 0.6950
# Epoch 6/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.3932 - binary_crossentropy: 0.3932 - auc: 0.8559 - val_loss: 0.5630 - val_binary_crossentropy: 0.5630 - val_auc: 0.6923
# Epoch 7/100
# 782/782 [==============================] - 23s 29ms/step - loss: 0.3921 - binary_crossentropy: 0.3921 - auc: 0.8567 - val_loss: 0.5658 - val_binary_crossentropy: 0.5658 - val_auc: 0.6932
# Epoch 8/100
# 782/782 [==============================] - 23s 29ms/step - loss: 0.3923 - binary_crossentropy: 0.3923 - auc: 0.8562 - val_loss: 0.5719 - val_binary_crossentropy: 0.5719 - val_auc: 0.6919
# Epoch 9/100
# 782/782 [==============================] - 27s 34ms/step - loss: 0.3918 - binary_crossentropy: 0.3918 - auc: 0.8569 - val_loss: 0.5679 - val_binary_crossentropy: 0.5679 - val_auc: 0.6917
# Epoch 10/100
# 782/782 [==============================] - 47s 60ms/step - loss: 0.3917 - binary_crossentropy: 0.3917 - auc: 0.8569 - val_loss: 0.5669 - val_binary_crossentropy: 0.5669 - val_auc: 0.6929
# Epoch 11/100
# 782/782 [==============================] - 45s 58ms/step - loss: 0.3916 - binary_crossentropy: 0.3916 - auc: 0.8569 - val_loss: 0.5640 - val_binary_crossentropy: 0.5640 - val_auc: 0.6959
# Epoch 00011: early stopping

# %%
# 模型预测与评估
result = dnn_model.predict(test_input)
model_metric(np.array([i[0] for i in result]), test_df['label'].values)
# Out:
# 模型准确率:0.741172, AUC得分:0.6937285584957377, LogLoss:0.5628377597864209
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84    751819
#            1       0.47      0.34      0.39    248181
#
#     accuracy                           0.74   1000000
#    macro avg       0.64      0.61      0.62   1000000
# weighted avg       0.72      0.74      0.73   1000000
#
# ==========================================================
