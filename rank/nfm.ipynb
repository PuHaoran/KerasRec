# %% [markdown]
# ## NFM

# %%
import os
import numpy as np
import pandas as pd
from collections import namedtuple

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.python.keras.callbacks import EarlyStopping
from sklearn.preprocessing import  MinMaxScaler, LabelEncoder

from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.metrics import classification_report, roc_curve

# %% [markdown]
# ##### 获取数据

# %%
def get_criteo_data():
    """ 读取criteo数据集 """
    train_path = '../data/criteo/train.txt'
    test_path = '../data/criteo/test.txt'

    dense_column_names = ['I' + str(i) for i in range(1, 14)]
    sparse_column_names = ['C' + str(i) for i in range(14, 40)]
    column_names = ['label'] + dense_column_names + sparse_column_names

    train_df = pd.read_csv(train_path, names=column_names, sep='\t')
    test_df = pd.read_csv(test_path, names=column_names, sep='\t')
    return train_df, test_df, dense_column_names, sparse_column_names

train_df, test_df, dense_column_names, sparse_column_names = get_criteo_data()
print('train.shape: {}, test.shape: {}'.format(train_df.shape, test_df.shape))
# Out:
# train.shape: (1000000, 40), test.shape: (1000000, 40)

# %% [markdown]
# ##### 数据预处理

# %%
data = pd.concat([train_df, test_df], axis=0)

def data_processing(df, dense_column_names, sparse_column_names):
    """ 数据预处理 """
    df[dense_column_names] = df[dense_column_names].fillna(0.0)
    for f in dense_column_names:
        df[f] = df[f].apply(lambda x: np.log(x+1) if x > -1 else -1)
    
    df[sparse_column_names] = df[sparse_column_names].fillna("-1")
    for f in sparse_column_names:
        lbe = LabelEncoder()
        df[f] = lbe.fit_transform(df[f])
    return df[dense_column_names + sparse_column_names]

df = data_processing(data, dense_column_names, sparse_column_names)
df['label'] = data['label']

train_df, test_df = df.iloc[0:train_df.shape[0]], df.iloc[train_df.shape[0]:]
print('train.shape:{}, test.shape:{}'.format(train_df.shape, test_df.shape))
# Out:
# train.shape:(1000000, 40), test.shape:(1000000, 40)

# %% [markdown]
# ##### 模型构建

# %%
SparseFeature = namedtuple('SparseFeature', ['name', 'vocabulary_size', 'embedding_size'])
DenseFeature = namedtuple('DenseFeature', ['name', 'dimension'])

# 定义特征列
linear_feature_columns = [SparseFeature(f, vocabulary_size=df[f].nunique(), embedding_size=4) for f in sparse_column_names] + \
[DenseFeature(f, 1,) for f in dense_column_names]

dnn_feature_columns = [SparseFeature(f, vocabulary_size=df[f].nunique(), embedding_size=4) for f in sparse_column_names] + \
[DenseFeature(f, 1,) for f in dense_column_names]

# %%
def build_input_layers(feature_columns):
    """ 构建输入层 """
    dense_input_dict, sparse_input_dict = {}, {}
    for f in feature_columns:
        if isinstance(f, DenseFeature):
            dense_input_dict[f.name] = Input(shape=(f.dimension, ), name=f.name)
        elif isinstance(f, SparseFeature):
            sparse_input_dict[f.name] = Input(shape=(1, ), name=f.name)
    return dense_input_dict, sparse_input_dict

def build_embedding_layers(feature_columns, is_linear):
    """ 构建embedding层 """
    embedding_layer_dict = {}
    sparse_feature_columns = list(filter(lambda x: isinstance(x, SparseFeature), feature_columns))
    if is_linear:
        for f in sparse_feature_columns:
            embedding_layer_dict[f.name] = Embedding(f.vocabulary_size+1, 1, name='1d_emb_' + f.name)
    else:
        for f in sparse_feature_columns:
            embedding_layer_dict[f.name] = Embedding(f.vocabulary_size+1, f.embedding_size, name='kd_emb_' + f.name)
    return embedding_layer_dict

def get_linear_logits(dense_input_dict, sparse_input_dict, sparse_feature_columns):
    """ 数值特征拼接一起传入全连接层 + 类别特征onehot，flatten，add """
    concat_dense_inputs = Concatenate(axis=1)(list(dense_input_dict.values()))
    dense_logits_output = Dense(1)(concat_dense_inputs)
    
    embedding_layer_dict = build_embedding_layers(sparse_feature_columns, is_linear=True)
    
    # embedding(input)查表操作，返回对应input的嵌入向量
    sparse_1d_embed_list = []
    for f in sparse_feature_columns:
        _input = sparse_input_dict[f.name]
        _embed = Flatten()(embedding_layer_dict[f.name](_input))
        sparse_1d_embed_list.append(_embed)
    
    sparse_logits_output = Add()(sparse_1d_embed_list)
    linear_logits = Add()([dense_logits_output, sparse_logits_output])
    return linear_logits

class BiInteractionPooling(Layer):
    """ embedding向量集合两两点乘(对应位置相乘)后相加 """
    def __init__(self):
        super(BiInteractionPooling, self).__init__()
    
    def call(self, inputs):
        concat_embed_values = inputs
        #print('concat_embed_values.shape: ', concat_embed_values.shape) # (None, 26, 4)
        sum_square = tf.square(tf.reduce_sum(concat_embed_values, axis=1, keepdims=False)) # (None, 4)
        #print('sum_square.shape: ', sum_square.shape)
        square_sum = tf.reduce_sum(concat_embed_values * concat_embed_values, axis=1, keepdims=False) # (None, 4)
        #print('square_sum.shape: ', square_sum.shape)
        output = 0.5*(sum_square - square_sum) # 和的平方-平方的和 (None, 4)
        return output
    
    def compute_output_shape(self, input_shape):
        return (None, input_shape[2])


def build_bi_interaction_pooling_layers(sparse_input_dict, sparse_feature_columns, embedding_layer_dict):
    sparse_kd_embed_list = []
    for f in sparse_feature_columns:
        _input = sparse_input_dict[f.name] 
        _embed = embedding_layer_dict[f.name]
        embed_layer = _embed(_input)
        sparse_kd_embed_list.append(embed_layer)
    #print('sparse_kd_embed_list: ', sparse_kd_embed_list)
    concat_sparse_kd_embed = Concatenate(axis=1)(sparse_kd_embed_list)
    pooling_out = BiInteractionPooling()(concat_sparse_kd_embed)
    return pooling_out
        
def model_metric(prob, label, thr=0.5):
    """ 模型评估 """
    # AUC
    fpr, tpr, threshold = metrics.roc_curve(label, prob)
    auc = metrics.auc(fpr, tpr)
    score = metrics.accuracy_score(label, prob > thr)
    # LogLoss
    logloss = log_loss(label, prob)
    print('模型准确率:{}, AUC得分:{}, LogLoss:{}'.format(score, auc, logloss))
    print(classification_report(label, prob > thr, digits=2))
    print('==========================================================')
    
def NFM(linear_feature_columns, dnn_feature_columns):
    """ Neural Factorization Machines """
    # Input
    dense_input_dict, sparse_input_dict = build_input_layers(linear_feature_columns + dnn_feature_columns)
    
    # wide侧(linear)
    linear_sparse_feature_columns = list(filter(lambda x: isinstance(x, SparseFeature), linear_feature_columns))
    input_list = list(dense_input_dict.values()) + list(sparse_input_dict.values())
    linear_logits = get_linear_logits(dense_input_dict, sparse_input_dict, linear_sparse_feature_columns)
    
    # deep侧(embedding bi-interaction pooling bn hidden)
    dnn_embedding_layer_dict = build_embedding_layers(dnn_feature_columns, is_linear=False)
    dnn_sparse_feature_columns = list(filter(lambda x: isinstance(x, SparseFeature), dnn_feature_columns))
    pooling_out = build_bi_interaction_pooling_layers(sparse_input_dict, dnn_sparse_feature_columns, dnn_embedding_layer_dict)
    
    # bn
    #bn_pooling_out = BatchNormalization()(pooling_out)
    # hidden
    dnn_out = Dropout(0.5)(Dense(8, activation='relu')(pooling_out))
    #dnn_out = Dropout(0.5)(Dense(512, activation='relu')(dnn_out))
    dnn_out = Dropout(0.5)(Dense(4, activation='relu')(dnn_out))
    dnn_logits = Dense(1)(dnn_out)
    
    output_logits = Add()([linear_logits, dnn_logits])
    output_layer = Activation("sigmoid")(output_logits)
    model = Model(input_list, output_layer)
    return model

model = NFM(linear_feature_columns, dnn_feature_columns)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# C14 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C15 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C16 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C17 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C18 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C19 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C20 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C21 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C22 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C23 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C24 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C25 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C26 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C27 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C28 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C29 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C30 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C31 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C32 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C33 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C34 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C35 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C36 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C37 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C38 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# C39 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# kd_emb_C14 (Embedding)          (None, 1, 4)         5484        C14[0][0]
# __________________________________________________________________________________________________
# kd_emb_C15 (Embedding)          (None, 1, 4)         2168        C15[0][0]
# __________________________________________________________________________________________________
# kd_emb_C16 (Embedding)          (None, 1, 4)         2388108     C16[0][0]
# __________________________________________________________________________________________________
# kd_emb_C17 (Embedding)          (None, 1, 4)         803144      C17[0][0]
# __________________________________________________________________________________________________
# kd_emb_C18 (Embedding)          (None, 1, 4)         1140        C18[0][0]
# __________________________________________________________________________________________________
# kd_emb_C19 (Embedding)          (None, 1, 4)         72          C19[0][0]
# __________________________________________________________________________________________________
# kd_emb_C20 (Embedding)          (None, 1, 4)         45552       C20[0][0]
# __________________________________________________________________________________________________
# kd_emb_C21 (Embedding)          (None, 1, 4)         2404        C21[0][0]
# __________________________________________________________________________________________________
# kd_emb_C22 (Embedding)          (None, 1, 4)         16          C22[0][0]
# __________________________________________________________________________________________________
# kd_emb_C23 (Embedding)          (None, 1, 4)         158664      C23[0][0]
# __________________________________________________________________________________________________
# kd_emb_C24 (Embedding)          (None, 1, 4)         19816       C24[0][0]
# __________________________________________________________________________________________________
# kd_emb_C25 (Embedding)          (None, 1, 4)         1994832     C25[0][0]
# __________________________________________________________________________________________________
# kd_emb_C26 (Embedding)          (None, 1, 4)         12392       C26[0][0]
# __________________________________________________________________________________________________
# kd_emb_C27 (Embedding)          (None, 1, 4)         108         C27[0][0]
# __________________________________________________________________________________________________
# kd_emb_C28 (Embedding)          (None, 1, 4)         40640       C28[0][0]
# __________________________________________________________________________________________________
# kd_emb_C29 (Embedding)          (None, 1, 4)         1487736     C29[0][0]
# __________________________________________________________________________________________________
# kd_emb_C30 (Embedding)          (None, 1, 4)         44          C30[0][0]
# __________________________________________________________________________________________________
# kd_emb_C31 (Embedding)          (None, 1, 4)         17028       C31[0][0]
# __________________________________________________________________________________________________
# kd_emb_C32 (Embedding)          (None, 1, 4)         7832        C32[0][0]
# __________________________________________________________________________________________________
# kd_emb_C33 (Embedding)          (None, 1, 4)         20          C33[0][0]
# __________________________________________________________________________________________________
# kd_emb_C34 (Embedding)          (None, 1, 4)         1773252     C34[0][0]
# __________________________________________________________________________________________________
# kd_emb_C35 (Embedding)          (None, 1, 4)         72          C35[0][0]
# __________________________________________________________________________________________________
# kd_emb_C36 (Embedding)          (None, 1, 4)         64          C36[0][0]
# __________________________________________________________________________________________________
# kd_emb_C37 (Embedding)          (None, 1, 4)         239508      C37[0][0]
# __________________________________________________________________________________________________
# kd_emb_C38 (Embedding)          (None, 1, 4)         328         C38[0][0]
# __________________________________________________________________________________________________
# kd_emb_C39 (Embedding)          (None, 1, 4)         173100      C39[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 26, 4)        0           kd_emb_C14[0][0]
#                                                                  kd_emb_C15[0][0]
#                                                                  kd_emb_C16[0][0]
#                                                                  kd_emb_C17[0][0]
#                                                                  kd_emb_C18[0][0]
#                                                                  kd_emb_C19[0][0]
#                                                                  kd_emb_C20[0][0]
#                                                                  kd_emb_C21[0][0]
#                                                                  kd_emb_C22[0][0]
#                                                                  kd_emb_C23[0][0]
#                                                                  kd_emb_C24[0][0]
#                                                                  kd_emb_C25[0][0]
#                                                                  kd_emb_C26[0][0]
#                                                                  kd_emb_C27[0][0]
#                                                                  kd_emb_C28[0][0]
#                                                                  kd_emb_C29[0][0]
#                                                                  kd_emb_C30[0][0]
#                                                                  kd_emb_C31[0][0]
#                                                                  kd_emb_C32[0][0]
#                                                                  kd_emb_C33[0][0]
#                                                                  kd_emb_C34[0][0]
#                                                                  kd_emb_C35[0][0]
#                                                                  kd_emb_C36[0][0]
#                                                                  kd_emb_C37[0][0]
#                                                                  kd_emb_C38[0][0]
#                                                                  kd_emb_C39[0][0]
# __________________________________________________________________________________________________
# bi_interaction_pooling (BiInter (None, 4)            0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          bi_interaction_pooling[0][0]
# __________________________________________________________________________________________________
# I1 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I2 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I3 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I4 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I5 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I6 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I7 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I8 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I9 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# I10 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I11 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I12 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# I13 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# 1d_emb_C14 (Embedding)          (None, 1, 1)         1371        C14[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C15 (Embedding)          (None, 1, 1)         542         C15[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C16 (Embedding)          (None, 1, 1)         597027      C16[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C17 (Embedding)          (None, 1, 1)         200786      C17[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C18 (Embedding)          (None, 1, 1)         285         C18[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C19 (Embedding)          (None, 1, 1)         18          C19[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C20 (Embedding)          (None, 1, 1)         11388       C20[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C21 (Embedding)          (None, 1, 1)         601         C21[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C22 (Embedding)          (None, 1, 1)         4           C22[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C23 (Embedding)          (None, 1, 1)         39666       C23[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C24 (Embedding)          (None, 1, 1)         4954        C24[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C25 (Embedding)          (None, 1, 1)         498708      C25[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C26 (Embedding)          (None, 1, 1)         3098        C26[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C27 (Embedding)          (None, 1, 1)         27          C27[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C28 (Embedding)          (None, 1, 1)         10160       C28[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C29 (Embedding)          (None, 1, 1)         371934      C29[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C30 (Embedding)          (None, 1, 1)         11          C30[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C31 (Embedding)          (None, 1, 1)         4257        C31[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C32 (Embedding)          (None, 1, 1)         1958        C32[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C33 (Embedding)          (None, 1, 1)         5           C33[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C34 (Embedding)          (None, 1, 1)         443313      C34[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C35 (Embedding)          (None, 1, 1)         18          C35[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C36 (Embedding)          (None, 1, 1)         16          C36[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C37 (Embedding)          (None, 1, 1)         59877       C37[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C38 (Embedding)          (None, 1, 1)         82          C38[0][0]
# __________________________________________________________________________________________________
# 1d_emb_C39 (Embedding)          (None, 1, 1)         43275       C39[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 13)           0           I1[0][0]
#                                                                  I2[0][0]
#                                                                  I3[0][0]
#                                                                  I4[0][0]
#                                                                  I5[0][0]
#                                                                  I6[0][0]
#                                                                  I7[0][0]
#                                                                  I8[0][0]
#                                                                  I9[0][0]
#                                                                  I10[0][0]
#                                                                  I11[0][0]
#                                                                  I12[0][0]
#                                                                  I13[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1)            0           1d_emb_C14[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1)            0           1d_emb_C15[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1)            0           1d_emb_C16[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1)            0           1d_emb_C17[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 1)            0           1d_emb_C18[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 1)            0           1d_emb_C19[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 1)            0           1d_emb_C20[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 1)            0           1d_emb_C21[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 1)            0           1d_emb_C22[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 1)            0           1d_emb_C23[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 1)            0           1d_emb_C24[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 1)            0           1d_emb_C25[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 1)            0           1d_emb_C26[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 1)            0           1d_emb_C27[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 1)            0           1d_emb_C28[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 1)            0           1d_emb_C29[0][0]
# __________________________________________________________________________________________________
# flatten_16 (Flatten)            (None, 1)            0           1d_emb_C30[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 1)            0           1d_emb_C31[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 1)            0           1d_emb_C32[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 1)            0           1d_emb_C33[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 1)            0           1d_emb_C34[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 1)            0           1d_emb_C35[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 1)            0           1d_emb_C36[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 1)            0           1d_emb_C37[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 1)            0           1d_emb_C38[0][0]
# __________________________________________________________________________________________________
# flatten_25 (Flatten)            (None, 1)            0           1d_emb_C39[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4)            36          dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            14          concatenate[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  flatten_7[0][0]
#                                                                  flatten_8[0][0]
#                                                                  flatten_9[0][0]
#                                                                  flatten_10[0][0]
#                                                                  flatten_11[0][0]
#                                                                  flatten_12[0][0]
#                                                                  flatten_13[0][0]
#                                                                  flatten_14[0][0]
#                                                                  flatten_15[0][0]
#                                                                  flatten_16[0][0]
#                                                                  flatten_17[0][0]
#                                                                  flatten_18[0][0]
#                                                                  flatten_19[0][0]
#                                                                  flatten_20[0][0]
#                                                                  flatten_21[0][0]
#                                                                  flatten_22[0][0]
#                                                                  flatten_23[0][0]
#                                                                  flatten_24[0][0]
#                                                                  flatten_25[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4)            0           dense_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1)            0           dense[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            5           dropout_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1)            0           add_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           add_2[0][0]
# ==================================================================================================
# Total params: 11,467,000
# Trainable params: 11,467,000
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 模型训练
train_input = {f: train_df[f] for f in dense_column_names + sparse_column_names}
test_input = {f: test_df[f] for f in dense_column_names + sparse_column_names}

my_callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, verbose=2, mode='auto')
]
model.compile('adam',
              loss='binary_crossentropy',
              metrics=["binary_crossentropy", tf.keras.metrics.AUC(name='auc')])
model.fit(train_input,
          train_df['label'].values,
          batch_size=1024,
          epochs=100,
          validation_split=0.2,
          callbacks=my_callbacks)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 58s 69ms/step - loss: 0.5641 - binary_crossentropy: 0.5641 - auc: 0.6668 - val_loss: 0.4807 - val_binary_crossentropy: 0.4807 - val_auc: 0.7569
# Epoch 2/100
# 782/782 [==============================] - 53s 68ms/step - loss: 0.4544 - binary_crossentropy: 0.4544 - auc: 0.7972 - val_loss: 0.4666 - val_binary_crossentropy: 0.4666 - val_auc: 0.7760
# Epoch 3/100
# 782/782 [==============================] - 54s 69ms/step - loss: 0.4188 - binary_crossentropy: 0.4188 - auc: 0.8365 - val_loss: 0.4733 - val_binary_crossentropy: 0.4733 - val_auc: 0.7698
# Epoch 4/100
# 782/782 [==============================] - 54s 69ms/step - loss: 0.3871 - binary_crossentropy: 0.3871 - auc: 0.8647 - val_loss: 0.4917 - val_binary_crossentropy: 0.4917 - val_auc: 0.7581
# Epoch 5/100
# 782/782 [==============================] - 53s 67ms/step - loss: 0.3623 - binary_crossentropy: 0.3623 - auc: 0.8837 - val_loss: 0.5180 - val_binary_crossentropy: 0.5180 - val_auc: 0.7467
# Epoch 6/100
# 782/782 [==============================] - 53s 68ms/step - loss: 0.3454 - binary_crossentropy: 0.3454 - auc: 0.8948 - val_loss: 0.5425 - val_binary_crossentropy: 0.5425 - val_auc: 0.7387
# Epoch 7/100
# 782/782 [==============================] - 55s 70ms/step - loss: 0.3333 - binary_crossentropy: 0.3333 - auc: 0.9024 - val_loss: 0.5584 - val_binary_crossentropy: 0.5584 - val_auc: 0.7358
# Epoch 8/100
# 782/782 [==============================] - 55s 71ms/step - loss: 0.3242 - binary_crossentropy: 0.3242 - auc: 0.9077 - val_loss: 0.5898 - val_binary_crossentropy: 0.5898 - val_auc: 0.7296
# Epoch 9/100
# 782/782 [==============================] - 55s 71ms/step - loss: 0.3166 - binary_crossentropy: 0.3166 - auc: 0.9120 - val_loss: 0.6075 - val_binary_crossentropy: 0.6075 - val_auc: 0.7272
# Epoch 10/100
# 782/782 [==============================] - 55s 70ms/step - loss: 0.3109 - binary_crossentropy: 0.3109 - auc: 0.9152 - val_loss: 0.6353 - val_binary_crossentropy: 0.6353 - val_auc: 0.7210
# Epoch 11/100
# 782/782 [==============================] - 56s 72ms/step - loss: 0.3059 - binary_crossentropy: 0.3059 - auc: 0.9179 - val_loss: 0.6305 - val_binary_crossentropy: 0.6305 - val_auc: 0.7260
# Epoch 12/100
# 782/782 [==============================] - 56s 71ms/step - loss: 0.3018 - binary_crossentropy: 0.3018 - auc: 0.9202 - val_loss: 0.6441 - val_binary_crossentropy: 0.6441 - val_auc: 0.7237
# Epoch 00012: early stopping

# %%
# 模型预测与评估
result = model.predict(test_input)
model_metric(np.array([i[0] for i in result]), test_df['label'].values)
# Out:
# 模型准确率:0.751251, AUC得分:0.7219195343771546, LogLoss:0.6439788159084661
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84    751819
#            1       0.50      0.44      0.47    248181
#
#     accuracy                           0.75   1000000
#    macro avg       0.66      0.65      0.65   1000000
# weighted avg       0.74      0.75      0.75   1000000
#
# ==========================================================
